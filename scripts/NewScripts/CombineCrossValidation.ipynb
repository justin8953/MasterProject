# %%
import pandas as pd 
import numpy as np
import os 

from sklearn.model_selection import cross_validate,train_test_split
from sklearn.preprocessing import LabelEncoder,scale
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.naive_bayes import ComplementNB,MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 11})

import re
import nltk
from nltk.corpus import stopwords


from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Activation, Conv1D, Dense, Embedding, Flatten, Input, Dropout, GlobalMaxPooling1D
from keras.metrics import categorical_accuracy
from keras.callbacks import  EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;-]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))
Number_RE = re.compile('[*^0-9]')
Bad_underline = re.compile('[*_*]')
RemoveTag = re.compile('&lt;|br&gt;|b&gt;|ul&gt;|li&gt;')

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = RemoveTag.sub('',text)
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = Number_RE.sub(' ', text) # replace Number symbols by space in text
    text = Bad_underline.sub(' ', text) # replace Underline symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text

# %%
def classNumberThreshold(arr):
    dropCategory = []

    for key,value in arr.items():
        if(value<=30):
            dropCategory.append(key)
    return dropCategory

# %%
df = pd.read_csv('../../example/combine.csv')
df.head()
# Out:
#                             uniq_id  \
# 0  c2e71e7c97489d4efa5eab796ae354ac
# 1  8d5196bb4b2ad74b557768e9f666c21c
# 2  833a87b0af3b84fe246d2ebf271af177
# 3  9c41fc08bd9e99ba7550816f00c9b9bd
# 4  f3f433714d8c535d28d0663c021e3769
#
#                                         product_name  \
# 0  Zyxel VMG1312-B10A VDSL2 Wireless N VDSL2 4-po...
# 1  Zyxel PLA4231 500 Mbps Powerline Wireless N Ex...
# 2                                     Zyxel PLA-4205
# 3                                    Zyxel p-661h-d1
# 4       Zyxel NWA1100N 802.11 b/g/n PoE Access Point
#
#                                          description category_main  \
# 0  Buy Zyxel VMG1312-B10A VDSL2 Wireless N VDSL2 ...     computers
# 1  Buy Zyxel PLA4231 500 Mbps Powerline Wireless ...     computers
# 2  Buy Zyxel PLA-4205 only for Rs. 8100 from Flip...     computers
# 3  Buy Zyxel p-661h-d1 only for Rs. 4042 from Fli...     computers
# 4  Buy Zyxel NWA1100N 802.11 b/g/n PoE Access Poi...     computers
#
#         category_sub1 category_sub2  category  subcategory
# 0  network components       routers    400000       400200
# 1  network components       routers    400000       400200
# 2  network components       routers    400000       400200
# 3  network components       routers    400000       400200
# 4  network components       routers    400000       400200

# %%
def checkNanin(text):
    text = str(text)
    if(text=="nan"):
        return ""
    else:
        return text
df.description = df.description.apply(checkNanin)  
df.description = df['description'].apply(clean_text)
df = df[pd.notnull(df['category'])]
df = df[pd.notnull(df['uniq_id'])]
df = df[pd.notnull(df['description'])]
df = df.dropna(subset=['description'])

# %%
dropCategoryCode  = classNumberThreshold(df.category.value_counts())
dropSubCategoryCode  = classNumberThreshold(df.subcategory.value_counts())

for i in dropCategoryCode:
    df = df[df.category!=i]
    
for i in dropSubCategoryCode:
    df = df[df.subcategory!=i]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28540 entries, 0 to 28689
# Data columns (total 8 columns):
# uniq_id          28540 non-null object
# product_name     28540 non-null object
# description      28540 non-null object
# category_main    27101 non-null object
# category_sub1    27101 non-null object
# category_sub2    23396 non-null object
# category         28540 non-null int64
# subcategory      28540 non-null int64
# dtypes: int64(2), object(6)
# memory usage: 2.0+ MB

# %%
le = LabelEncoder()
le.fit(df.category)
target = le.classes_
labels = le.transform(df.category)

le.fit(df.subcategory)
subtarget = le.classes_
sublabels = le.transform(df.subcategory)

# %%
tfidfconverter = TfidfVectorizer(min_df=5, max_df=0.7)
X = tfidfconverter.fit_transform(df.description)

# %%
K = [2, 3, 4, 5, 10]
testSize = [ 1/ele for ele in K ]
CNBCresults = []
MNBCresults = []
for ele in K:
    MNBC = MultinomialNB()
    CNBC = ComplementNB()
    mnbcresult = cross_validate(MNBC, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    cnbcresult = cross_validate(CNBC, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    CNBCresults.append(cnbcresult)
    MNBCresults.append(mnbcresult)
# Out:
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
SVCresults = []
for ele in K:
    linearsvc = LinearSVC(random_state=42, class_weight="balanced")
    result = cross_validate(linearsvc, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    SVCresults.append(result)

# %%
def result_report(results):
    mean_result_report = []
    for ele in results:
        mean_result = {}
        for key,value in ele.items():
            mean_result[key] = round(np.mean(value),2)
        mean_result_report.append(mean_result)
    return mean_result_report

MNBCReport = result_report(MNBCresults)
CNBCReport = result_report(CNBCresults)
SVCReport = result_report(SVCresults)

# %%
MNBCReport,CNBCReport,SVCReport
# Out:
# ([{'fit_time': 0.01,
#    'score_time': 0.03,
#    'test_f1_micro': 0.85,
#    'train_f1_micro': 0.92,
#    'test_f1_macro': 0.48,
#    'train_f1_macro': 0.7,
#    'test_f1_weighted': 0.82,
#    'train_f1_weighted': 0.9,
#    'test_accuracy': 0.85,
#    'train_accuracy': 0.92},
#   {'fit_time': 0.02,
#    'score_time': 0.02,
#    'test_f1_micro': 0.87,
#    'train_f1_micro': 0.92,
#    'test_f1_macro': 0.52,
#    'train_f1_macro': 0.73,
#    'test_f1_weighted': 0.84,
#    'train_f1_weighted': 0.91,
#    'test_accuracy': 0.87,
#    'train_accuracy': 0.92},
#   {'fit_time': 0.02,
#    'score_time': 0.02,
#    'test_f1_micro': 0.87,
#    'train_f1_micro': 0.92,
#    'test_f1_macro': 0.57,
#    'train_f1_macro': 0.73,
#    'test_f1_weighted': 0.85,
#    'train_f1_weighted': 0.91,
#    'test_accuracy': 0.87,
#    'train_accuracy': 0.92},
#   {'fit_time': 0.02,
#    'score_time': 0.01,
#    'test_f1_micro': 0.88,
#    'train_f1_micro': 0.92,
#    'test_f1_macro': 0.58,
#    'train_f1_macro': 0.74,
#    'test_f1_weighted': 0.85,
#    'train_f1_weighted': 0.91,
#    'test_accuracy': 0.88,
#    'train_accuracy': 0.92},
#   {'fit_time': 0.02,
#    'score_time': 0.01,
#    'test_f1_micro': 0.89,
#    'train_f1_micro': 0.92,
#    'test_f1_macro': 0.62,
#    'train_f1_macro': 0.76,
#    'test_f1_weighted': 0.87,
#    'train_f1_weighted': 0.91,
#    'test_accuracy': 0.89,
#    'train_accuracy': 0.92}],
#  [{'fit_time': 0.01,
#    'score_time': 0.03,
#    'test_f1_micro': 0.9,
#    'train_f1_micro': 0.96,
#    'test_f1_macro': 0.71,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.89,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.9,
#    'train_accuracy': 0.96},
#   {'fit_time': 0.02,
#    'score_time': 0.02,
#    'test_f1_micro': 0.91,
#    'train_f1_micro': 0.96,
#    'test_f1_macro': 0.73,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.9,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.91,
#    'train_accuracy': 0.96},
#   {'fit_time': 0.02,
#    'score_time': 0.02,
#    'test_f1_micro': 0.92,
#    'train_f1_micro': 0.95,
#    'test_f1_macro': 0.78,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.91,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.92,
#    'train_accuracy': 0.95},
#   {'fit_time': 0.02,
#    'score_time': 0.01,
#    'test_f1_micro': 0.93,
#    'train_f1_micro': 0.95,
#    'test_f1_macro': 0.78,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.92,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.93,
#    'train_accuracy': 0.95},
#   {'fit_time': 0.02,
#    'score_time': 0.01,
#    'test_f1_micro': 0.93,
#    'train_f1_micro': 0.95,
#    'test_f1_macro': 0.78,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.92,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.93,
#    'train_accuracy': 0.95}],
#  [{'fit_time': 0.51,
#    'score_time': 0.03,
#    'test_f1_micro': 0.94,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.83,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.94,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.94,
#    'train_accuracy': 1.0},
#   {'fit_time': 0.67,
#    'score_time': 0.02,
#    'test_f1_micro': 0.95,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.85,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.95,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.95,
#    'train_accuracy': 1.0},
#   {'fit_time': 0.74,
#    'score_time': 0.02,
#    'test_f1_micro': 0.95,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.89,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.95,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.95,
#    'train_accuracy': 1.0},
#   {'fit_time': 0.81,
#    'score_time': 0.01,
#    'test_f1_micro': 0.96,
#    'train_f1_micro': 0.99,
#    'test_f1_macro': 0.9,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.96,
#    'train_f1_weighted': 0.99,
#    'test_accuracy': 0.96,
#    'train_accuracy': 0.99},
#   {'fit_time': 0.97,
#    'score_time': 0.01,
#    'test_f1_micro': 0.96,
#    'train_f1_micro': 0.99,
#    'test_f1_macro': 0.9,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.96,
#    'train_f1_weighted': 0.99,
#    'test_accuracy': 0.96,
#    'train_accuracy': 0.99}])

# %%
embedding_dim = 300 # We use 100 dimensional glove vectors
glove_dir = '../../glove.6B' # This is the folder with the dataset
embeddings_index = {} # We create a dictionary of word -> embedding
with open(os.path.join(glove_dir, 'glove.6B.300d.txt')) as f:
    for line in f:
        values = line.split()
        word = values[0] # The first value is the word, the rest are the values of the embedding
        embedding = np.asarray(values[1:], dtype='float32') # Load embedding
        embeddings_index[word] = embedding # Add embedding to our embedding dictionary
    print('Found {:,} word vectors in GloVe.'.format(len(embeddings_index)))
# Out:
# Found 400,000 word vectors in GloVe.

# %%
def tokenizer_and_pad_sequence (Xtrain,Xtest,vocab_size,embeddings_index):
    tokenizer = Tokenizer(num_words=vocab_size) # Setup tokenizer
    tokenizer.fit_on_texts(Xtrain)
    
    sequences = tokenizer.texts_to_sequences(Xtrain)
    sequences_test = tokenizer.texts_to_sequences(Xtest)
    
    trainlengths = [len(ele) for ele in sequences]
    testlengths = [len(ele) for ele in sequences_test]
    max_length = min(max(trainlengths),max(testlengths))
    
    train = pad_sequences(sequences,maxlen= max_length)
    test = pad_sequences(sequences_test,maxlen = max_length)
    
    word_index = tokenizer.word_index
    embedding_dim = 300
    nb_words = min(vocab_size, len(word_index)) # How many words are there actually
    embedding_matrix = np.zeros((nb_words, embedding_dim))
    # The vectors need to be in the same position as their index. 
    # Meaning a word with token 1 needs to be in the second row (rows start with zero) and so on
    # Loop over all words in the word index
    for word, i in word_index.items():
        # If we are above the amount of words we want to use we do nothing
        if i >= vocab_size: 
            continue
        # Get the embedding vector for the word
        embedding_vector = embeddings_index.get(word)
        # If there is an embedding vector, put it in the embedding matrix
        if embedding_vector is not None: 
            embedding_matrix[i] = embedding_vector
    return train, test, max_length, embedding_matrix

def model_settings(length,vocabSize,embeddingMatrix,outputnum):
        embedding_dim = 300
        model = Sequential()
        model.add(Embedding(vocab_size, embedding_dim, input_length=length, weights = [embedding_matrix], 
                                trainable = False))
        model.add(Conv1D(200,3,padding='valid',activation='relu',strides=1))        
        # we use max pooling:
        model.add(GlobalMaxPooling1D())
        # We add a vanilla hidden layer:
        model.add(Dense(250))
        model.add(Dropout(0.2))
        model.add(Dense(outputnum, activation='softmax'))
        model.summary()
        return model

def fit_evaluate(model,Xtrain, ytrain,Xtest,ytest):
    EPOCHS = 10
    BATCH_SIZE = 100
    #set early stopping criteria
    pat = 5 #this is the number of epochs with no improvment after which the training will stop
    early_stopping = EarlyStopping(monitor='val_loss', patience=pat, verbose=1)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[categorical_accuracy])
    result = model.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=BATCH_SIZE, 
                        callbacks=[early_stopping], 
              verbose=1, validation_split=0.1)
    score = model.evaluate(Xtest, ytest, batch_size=BATCH_SIZE)
    return result,score

# %%
vocab_size = len(tfidfconverter.get_feature_names())
KFoldTrainResults = []
KFoldTestResults  = []
for i in testSize:
    print("------ "+str(i)+" testing size ------\n")
    Xtrain, Xtest, ytrain , ytest = train_test_split(df['description'].apply(str), labels, test_size= i, random_state = 42)
    categoricalLabel = to_categorical(ytrain)
    categoricalTestLabel = to_categorical(ytest)
    train, test, max_length, embedding_matrix =  tokenizer_and_pad_sequence(Xtrain,Xtest,vocab_size,embeddings_index)
    model = model_settings(max_length,vocab_size,embedding_matrix,len(np.unique(ytrain)))
    result,score = fit_evaluate(model,train,categoricalLabel,test,categoricalTestLabel)
    KFoldTrainResults.append(result)
    KFoldTestResults.append(score)
# Out:
# ------ 0.5 testing size ------
# WARNING: Logging before flag parsing goes to stderr.
# W0830 10:06:23.868863 139730385000256 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0830 10:06:23.888269 139730385000256 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0830 10:06:23.890601 139730385000256 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0830 10:06:23.898803 139730385000256 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0830 10:06:23.899806 139730385000256 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0830 10:06:24.033396 139730385000256 deprecation.py:506] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0830 10:06:24.059273 139730385000256 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0830 10:06:24.081501 139730385000256 deprecation.py:323] From /home/justin/mscproject/app/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 517, 300)          3333900
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 515, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 12843 samples, validate on 1427 samples
# Epoch 1/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0809 - categorical_accuracy: 0.8718 - val_loss: 0.0289 - val_categorical_accuracy: 0.9523
# Epoch 2/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0199 - categorical_accuracy: 0.9726 - val_loss: 0.0264 - val_categorical_accuracy: 0.9706
# Epoch 3/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0086 - categorical_accuracy: 0.9898 - val_loss: 0.0186 - val_categorical_accuracy: 0.9713
# Epoch 4/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0047 - categorical_accuracy: 0.9958 - val_loss: 0.0207 - val_categorical_accuracy: 0.9748
# Epoch 5/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0025 - categorical_accuracy: 0.9982 - val_loss: 0.0182 - val_categorical_accuracy: 0.9755
# Epoch 6/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0019 - categorical_accuracy: 0.9986 - val_loss: 0.0191 - val_categorical_accuracy: 0.9797
# Epoch 7/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0017 - categorical_accuracy: 0.9988 - val_loss: 0.0183 - val_categorical_accuracy: 0.9797
# Epoch 8/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0019 - categorical_accuracy: 0.9987 - val_loss: 0.0217 - val_categorical_accuracy: 0.9741
# Epoch 9/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0017 - categorical_accuracy: 0.9984 - val_loss: 0.0179 - val_categorical_accuracy: 0.9762
# Epoch 10/10
# 12843/12843 [==============================] - 26s 2ms/step - loss: 0.0015 - categorical_accuracy: 0.9991 - val_loss: 0.0239 - val_categorical_accuracy: 0.9727
# 14270/14270 [==============================] - 11s 803us/step
# ------ 0.3333333333333333 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 529, 300)          3333900
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 527, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 200)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 17123 samples, validate on 1903 samples
# Epoch 1/10
# 17123/17123 [==============================] - 35s 2ms/step - loss: 0.0682 - categorical_accuracy: 0.8969 - val_loss: 0.0245 - val_categorical_accuracy: 0.9611
# Epoch 2/10
# 17123/17123 [==============================] - 35s 2ms/step - loss: 0.0170 - categorical_accuracy: 0.9769 - val_loss: 0.0189 - val_categorical_accuracy: 0.9706
# Epoch 3/10
# 17123/17123 [==============================] - 40s 2ms/step - loss: 0.0075 - categorical_accuracy: 0.9905 - val_loss: 0.0195 - val_categorical_accuracy: 0.9732
# Epoch 4/10
# 17123/17123 [==============================] - 40s 2ms/step - loss: 0.0052 - categorical_accuracy: 0.9938 - val_loss: 0.0272 - val_categorical_accuracy: 0.9721
# Epoch 5/10
# 17123/17123 [==============================] - 55s 3ms/step - loss: 0.0037 - categorical_accuracy: 0.9964 - val_loss: 0.0225 - val_categorical_accuracy: 0.9727
# Epoch 6/10
# 17123/17123 [==============================] - 68s 4ms/step - loss: 0.0036 - categorical_accuracy: 0.9971 - val_loss: 0.0240 - val_categorical_accuracy: 0.9695
# Epoch 7/10
# 17123/17123 [==============================] - 72s 4ms/step - loss: 0.0035 - categorical_accuracy: 0.9964 - val_loss: 0.0238 - val_categorical_accuracy: 0.9690
# Epoch 00007: early stopping
# 9514/9514 [==============================] - 14s 1ms/step
# ------ 0.25 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 530, 300)          3333900
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 528, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 200)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 19264 samples, validate on 2141 samples
# Epoch 1/10
# 19264/19264 [==============================] - 81s 4ms/step - loss: 0.0609 - categorical_accuracy: 0.9071 - val_loss: 0.0208 - val_categorical_accuracy: 0.9743
# Epoch 2/10
# 19264/19264 [==============================] - 81s 4ms/step - loss: 0.0165 - categorical_accuracy: 0.9773 - val_loss: 0.0176 - val_categorical_accuracy: 0.9762
# Epoch 3/10
# 19264/19264 [==============================] - 81s 4ms/step - loss: 0.0070 - categorical_accuracy: 0.9917 - val_loss: 0.0173 - val_categorical_accuracy: 0.9757
# Epoch 4/10
# 19264/19264 [==============================] - 80s 4ms/step - loss: 0.0051 - categorical_accuracy: 0.9941 - val_loss: 0.0172 - val_categorical_accuracy: 0.9776
# Epoch 5/10
# 19264/19264 [==============================] - 79s 4ms/step - loss: 0.0032 - categorical_accuracy: 0.9970 - val_loss: 0.0189 - val_categorical_accuracy: 0.9785
# Epoch 6/10
# 19264/19264 [==============================] - 80s 4ms/step - loss: 0.0024 - categorical_accuracy: 0.9982 - val_loss: 0.0205 - val_categorical_accuracy: 0.9794
# Epoch 7/10
# 19264/19264 [==============================] - 80s 4ms/step - loss: 0.0029 - categorical_accuracy: 0.9978 - val_loss: 0.0173 - val_categorical_accuracy: 0.9804
# Epoch 8/10
# 19264/19264 [==============================] - 80s 4ms/step - loss: 0.0030 - categorical_accuracy: 0.9975 - val_loss: 0.0225 - val_categorical_accuracy: 0.9766
# Epoch 9/10
# 19264/19264 [==============================] - 80s 4ms/step - loss: 0.0037 - categorical_accuracy: 0.9966 - val_loss: 0.0233 - val_categorical_accuracy: 0.9729
# Epoch 00009: early stopping
# 7135/7135 [==============================] - 10s 1ms/step
# ------ 0.2 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 525, 300)          3333900
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 523, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 200)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 20548 samples, validate on 2284 samples
# Epoch 1/10
# 20548/20548 [==============================] - 107s 5ms/step - loss: 0.0581 - categorical_accuracy: 0.9119 - val_loss: 0.0185 - val_categorical_accuracy: 0.9742
# Epoch 2/10
# 20548/20548 [==============================] - 113s 6ms/step - loss: 0.0152 - categorical_accuracy: 0.9799 - val_loss: 0.0256 - val_categorical_accuracy: 0.9628
# Epoch 3/10
# 20548/20548 [==============================] - 113s 6ms/step - loss: 0.0076 - categorical_accuracy: 0.9894 - val_loss: 0.0181 - val_categorical_accuracy: 0.9729
# Epoch 4/10
# 20548/20548 [==============================] - 115s 6ms/step - loss: 0.0044 - categorical_accuracy: 0.9949 - val_loss: 0.0170 - val_categorical_accuracy: 0.9764
# Epoch 5/10
# 20548/20548 [==============================] - 112s 5ms/step - loss: 0.0032 - categorical_accuracy: 0.9973 - val_loss: 0.0197 - val_categorical_accuracy: 0.9794
# Epoch 6/10
# 20548/20548 [==============================] - 113s 6ms/step - loss: 0.0035 - categorical_accuracy: 0.9970 - val_loss: 0.0247 - val_categorical_accuracy: 0.9742
# Epoch 7/10
# 20548/20548 [==============================] - 113s 5ms/step - loss: 0.0032 - categorical_accuracy: 0.9968 - val_loss: 0.0250 - val_categorical_accuracy: 0.9715
# Epoch 8/10
# 20548/20548 [==============================] - 112s 5ms/step - loss: 0.0034 - categorical_accuracy: 0.9971 - val_loss: 0.0241 - val_categorical_accuracy: 0.9724
# Epoch 9/10
# 20548/20548 [==============================] - 113s 5ms/step - loss: 0.0037 - categorical_accuracy: 0.9967 - val_loss: 0.0235 - val_categorical_accuracy: 0.9777
# Epoch 00009: early stopping
# 5708/5708 [==============================] - 10s 2ms/step
# ------ 0.1 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 526, 300)          3333900
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 524, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 200)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 23117 samples, validate on 2569 samples
# Epoch 1/10
# 23117/23117 [==============================] - 118s 5ms/step - loss: 0.0607 - categorical_accuracy: 0.9059 - val_loss: 0.0243 - val_categorical_accuracy: 0.9669
# Epoch 2/10
# 23117/23117 [==============================] - 86s 4ms/step - loss: 0.0167 - categorical_accuracy: 0.9782 - val_loss: 0.0189 - val_categorical_accuracy: 0.9735
# Epoch 3/10
# 23117/23117 [==============================] - 84s 4ms/step - loss: 0.0079 - categorical_accuracy: 0.9906 - val_loss: 0.0203 - val_categorical_accuracy: 0.9735
# Epoch 4/10
# 23117/23117 [==============================] - 83s 4ms/step - loss: 0.0040 - categorical_accuracy: 0.9956 - val_loss: 0.0201 - val_categorical_accuracy: 0.9774
# Epoch 5/10
# 23117/23117 [==============================] - 85s 4ms/step - loss: 0.0048 - categorical_accuracy: 0.9945 - val_loss: 0.0246 - val_categorical_accuracy: 0.9747
# Epoch 6/10
# 23117/23117 [==============================] - 83s 4ms/step - loss: 0.0046 - categorical_accuracy: 0.9958 - val_loss: 0.0247 - val_categorical_accuracy: 0.9720
# Epoch 7/10
# 23117/23117 [==============================] - 82s 4ms/step - loss: 0.0044 - categorical_accuracy: 0.9949 - val_loss: 0.0250 - val_categorical_accuracy: 0.9747
# Epoch 00007: early stopping
# 2854/2854 [==============================] - 4s 1ms/step

# %%
fig, (ax,ax2) = plt.subplots(2, 1,figsize=(5,10))
for ele in KFoldTrainResults:
    currentTestsize = testSize[KFoldTrainResults.index(ele)]
    ax.plot(ele.history['categorical_accuracy'],label= str(round(1-currentTestsize,2))+" testing size")

    ax.legend()
ax.set_title('Categorical Accuracy Accuracy')
ax.set_xlabel("Epoch")
ax.set_ylabel("Validation categoryical accuracy")

for ele in KFoldTrainResults:
    currentTestsize = testSize[KFoldTrainResults.index(ele)]
    ax2.plot(ele.history['val_categorical_accuracy'],label= str(round(1-currentTestsize,2))+" testing size")
    ax2.legend()
ax2.set_title('Validation categoryical accuracy')
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Validation categoryical accuracy")

fig.savefig("CombineCNNsTrainCrossValidation.png", bbox_inches='tight')

# %%
fig, (ax1,ax3) = plt.subplots(2, 1,figsize=(5,10))
fig.subplots_adjust(hspace=0.5)
trainSize = [ (1-1/ele) for ele in K ]
ytrainTimeMNBC = [ ele['fit_time'] for ele in MNBCReport]
ytrainTimeCNBC = [ ele['fit_time'] for ele in CNBCReport]

ytrainTimeSVC = [ ele['fit_time'] for ele in SVCReport]
ytestTimeMNBC = [ ele['score_time'] for ele in MNBCReport]
ytestTimeCNBC = [ ele['score_time'] for ele in CNBCReport]
ytestTimeSVC = [ ele['score_time'] for ele in SVCReport]
yAccCNNs = [ele[1] for ele in KFoldTestResults]
yAccMNBC = [ ele['test_accuracy'] for ele in MNBCReport]
yAccCNBC = [ ele['test_accuracy'] for ele in CNBCReport]
yAccSVC = [ ele['test_accuracy'] for ele in SVCReport]
line1, = ax1.plot(trainSize, ytrainTimeMNBC, color="tab:red", label = "MNBC Training" )
line2, = ax1.plot(trainSize, ytrainTimeCNBC, color="tab:blue", label = "CNBC Training" )
line3, = ax1.plot(trainSize, ytrainTimeSVC, color="tab:orange", label = "SVC Training" )
line1.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break
line2.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break
line3.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break

ax1.set_title('Training and Testing Time')
ax1.set_xlabel("Size of training set")
ax1.set_ylabel("Training time (us)")
step1 = (max(ytrainTimeSVC) - min(ytrainTimeSVC))/len(ytrainTimeSVC)
ax1.yaxis.set_ticks(np.arange(0,max(ytrainTimeSVC),step1))
ax1.xaxis.set_ticks(np.arange(0,1,0.1))

# ax1.grid()
ax1.legend(loc=4)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(trainSize, ytestTimeMNBC, color="tab:red", label = "MNBC Testing" )
ax2.plot(trainSize, ytestTimeCNBC, color="tab:blue", label = "CNBC Testing" )
ax2.plot(trainSize, ytestTimeSVC, color="tab:orange", label = "SVC Testing" )
ax2.set_ylabel("Testing time (us)")
step2 = (max(ytestTimeSVC) - min(ytestTimeSVC))/len(ytestTimeSVC)
ax2.yaxis.set_ticks(np.arange(0,max(ytestTimeSVC),step2))
# ax2.grid()
ax2.legend(loc=1)

ax3.plot(trainSize, yAccMNBC, color="tab:red", label = "MNBC" )
ax3.plot(trainSize, yAccCNBC, color="tab:blue", label = "CNBC" )
ax3.plot(trainSize, yAccSVC, color="tab:orange", label = "SVC" )
ax3.plot(trainSize, yAccCNNs, color="tab:green", label = "CNNs" )
ax3.set_title('Accuracy')
ax3.set_xlabel("Size of training set")
ax3.set_ylabel("Accuracy")

ax3.grid()
ax3.legend()

fig.savefig("CombineCrossValidation.png", bbox_inches='tight')


print(K[np.argmax(yAccMNBC)])
print(K[np.argmax(yAccCNBC)])
print(K[np.argmax(yAccSVC)])
print(K[np.argmax(yAccCNNs)])
# Out:
# 10
# 5
# 5
# 5
