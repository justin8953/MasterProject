# %%
import pandas as pd 
import numpy as np
import os 

from sklearn.model_selection import cross_validate,train_test_split
from sklearn.preprocessing import LabelEncoder,scale
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.naive_bayes import ComplementNB
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 11})

import re
import nltk
from nltk.corpus import stopwords


from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Activation, Conv1D, Dense, Embedding, Flatten, Input, Dropout, GlobalMaxPooling1D
from keras.metrics import categorical_accuracy
from keras.callbacks import  EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;-]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))
Number_RE = re.compile('[*^0-9]')
Bad_underline = re.compile('[*_*]')
RemoveTag = re.compile('&lt;|br&gt;|b&gt;|ul&gt;|li&gt;')

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = RemoveTag.sub('',text)
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = Number_RE.sub(' ', text) # replace Number symbols by space in text
    text = Bad_underline.sub(' ', text) # replace Underline symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text

# %%
def classNumberThreshold(arr):
    dropCategory = []

    for key,value in arr.items():
        if(value<=30):
            dropCategory.append(key)
    return dropCategory

# %%
df = pd.read_csv('../../example/combine.csv')
df.head()
# Out:
#                             uniq_id  \
# 0  c2e71e7c97489d4efa5eab796ae354ac
# 1  8d5196bb4b2ad74b557768e9f666c21c
# 2  833a87b0af3b84fe246d2ebf271af177
# 3  9c41fc08bd9e99ba7550816f00c9b9bd
# 4  f3f433714d8c535d28d0663c021e3769
#
#                                         product_name  \
# 0  Zyxel VMG1312-B10A VDSL2 Wireless N VDSL2 4-po...
# 1  Zyxel PLA4231 500 Mbps Powerline Wireless N Ex...
# 2                                     Zyxel PLA-4205
# 3                                    Zyxel p-661h-d1
# 4       Zyxel NWA1100N 802.11 b/g/n PoE Access Point
#
#                                          description category_main  \
# 0  Buy Zyxel VMG1312-B10A VDSL2 Wireless N VDSL2 ...     computers
# 1  Buy Zyxel PLA4231 500 Mbps Powerline Wireless ...     computers
# 2  Buy Zyxel PLA-4205 only for Rs. 8100 from Flip...     computers
# 3  Buy Zyxel p-661h-d1 only for Rs. 4042 from Fli...     computers
# 4  Buy Zyxel NWA1100N 802.11 b/g/n PoE Access Poi...     computers
#
#         category_sub1 category_sub2  category  subcategory
# 0  network components       routers    400000       400200
# 1  network components       routers    400000       400200
# 2  network components       routers    400000       400200
# 3  network components       routers    400000       400200
# 4  network components       routers    400000       400200

# %%
def checkNanin(text):
    text = str(text)
    if(text=="nan"):
        return ""
    else:
        return text
df.description = df.description.apply(checkNanin)  
df.description = df['description'].apply(clean_text)
df = df[pd.notnull(df['category'])]
df = df[pd.notnull(df['uniq_id'])]
df = df[pd.notnull(df['description'])]
df = df.dropna(subset=['description'])

# %%
dropCategoryCode  = classNumberThreshold(df.category.value_counts())
dropSubCategoryCode  = classNumberThreshold(df.subcategory.value_counts())

for i in dropCategoryCode:
    df = df[df.category!=i]
    
for i in dropSubCategoryCode:
    df = df[df.subcategory!=i]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28540 entries, 0 to 28689
# Data columns (total 8 columns):
# uniq_id          28540 non-null object
# product_name     28540 non-null object
# description      28540 non-null object
# category_main    27101 non-null object
# category_sub1    27101 non-null object
# category_sub2    23396 non-null object
# category         28540 non-null int64
# subcategory      28540 non-null int64
# dtypes: int64(2), object(6)
# memory usage: 2.0+ MB

# %%
le = LabelEncoder()
le.fit(df.category)
target = le.classes_
labels = le.transform(df.category)

le.fit(df.subcategory)
subtarget = le.classes_
sublabels = le.transform(df.subcategory)

# %%
tfidfconverter = TfidfVectorizer(min_df=5, max_df=0.7)
X = tfidfconverter.fit_transform(df.description)

# %%
K = [2, 3, 4, 5, 10]
NBCresults = []
for ele in K:
    CNBC = ComplementNB()
    result = cross_validate(CNBC, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    NBCresults.append(result)
# Out:
# /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
SVCresults = []
for ele in K:
    linearsvc = LinearSVC(random_state=42, class_weight="balanced")
    result = cross_validate(linearsvc, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    SVCresults.append(result)

# %%
def result_report(results):
    mean_result_report = []
    for ele in results:
        mean_result = {}
        for key,value in ele.items():
            mean_result[key] = round(np.mean(value),2)
        mean_result_report.append(mean_result)
    return mean_result_report

NBCReport = result_report(NBCresults)
SVCReport = result_report(SVCresults)

# %%
NBCReport,SVCReport
# Out:
# ([{'fit_time': 0.08,
#    'score_time': 0.08,
#    'test_f1_micro': 0.9,
#    'train_f1_micro': 0.96,
#    'test_f1_macro': 0.71,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.89,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.9,
#    'train_accuracy': 0.96},
#   {'fit_time': 0.08,
#    'score_time': 0.07,
#    'test_f1_micro': 0.91,
#    'train_f1_micro': 0.96,
#    'test_f1_macro': 0.73,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.9,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.91,
#    'train_accuracy': 0.96},
#   {'fit_time': 0.07,
#    'score_time': 0.04,
#    'test_f1_micro': 0.92,
#    'train_f1_micro': 0.95,
#    'test_f1_macro': 0.78,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.91,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.92,
#    'train_accuracy': 0.95},
#   {'fit_time': 0.09,
#    'score_time': 0.06,
#    'test_f1_micro': 0.93,
#    'train_f1_micro': 0.95,
#    'test_f1_macro': 0.78,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.92,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.93,
#    'train_accuracy': 0.95},
#   {'fit_time': 0.09,
#    'score_time': 0.02,
#    'test_f1_micro': 0.93,
#    'train_f1_micro': 0.95,
#    'test_f1_macro': 0.78,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.92,
#    'train_f1_weighted': 0.95,
#    'test_accuracy': 0.93,
#    'train_accuracy': 0.95}],
#  [{'fit_time': 1.41,
#    'score_time': 0.07,
#    'test_f1_micro': 0.94,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.83,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.94,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.94,
#    'train_accuracy': 1.0},
#   {'fit_time': 1.96,
#    'score_time': 0.05,
#    'test_f1_micro': 0.95,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.85,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.95,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.95,
#    'train_accuracy': 1.0},
#   {'fit_time': 2.43,
#    'score_time': 0.05,
#    'test_f1_micro': 0.95,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.89,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.95,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.95,
#    'train_accuracy': 1.0},
#   {'fit_time': 2.55,
#    'score_time': 0.04,
#    'test_f1_micro': 0.96,
#    'train_f1_micro': 0.99,
#    'test_f1_macro': 0.9,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.96,
#    'train_f1_weighted': 0.99,
#    'test_accuracy': 0.96,
#    'train_accuracy': 0.99},
#   {'fit_time': 2.18,
#    'score_time': 0.02,
#    'test_f1_micro': 0.96,
#    'train_f1_micro': 0.99,
#    'test_f1_macro': 0.9,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.96,
#    'train_f1_weighted': 0.99,
#    'test_accuracy': 0.96,
#    'train_accuracy': 0.99}])

# %%
embedding_dim = 300 # We use 100 dimensional glove vectors
glove_dir = '../../glove.6B' # This is the folder with the dataset
embeddings_index = {} # We create a dictionary of word -> embedding
with open(os.path.join(glove_dir, 'glove.6B.300d.txt')) as f:
    for line in f:
        values = line.split()
        word = values[0] # The first value is the word, the rest are the values of the embedding
        embedding = np.asarray(values[1:], dtype='float32') # Load embedding
        embeddings_index[word] = embedding # Add embedding to our embedding dictionary
    print('Found {:,} word vectors in GloVe.'.format(len(embeddings_index)))
# Out:
# Found 400,000 word vectors in GloVe.

# %%
def tokenizer_and_pad_sequence (Xtrain,Xtest,vocab_size,embeddings_index):
    tokenizer = Tokenizer(num_words=vocab_size) # Setup tokenizer
    tokenizer.fit_on_texts(Xtrain)
    
    sequences = tokenizer.texts_to_sequences(Xtrain)
    sequences_test = tokenizer.texts_to_sequences(Xtest)
    
    trainlengths = [len(ele) for ele in sequences]
    testlengths = [len(ele) for ele in sequences_test]
    max_length = min(max(trainlengths),max(testlengths))
    
    train = pad_sequences(sequences,maxlen= max_length)
    test = pad_sequences(sequences_test,maxlen = max_length)
    
    word_index = tokenizer.word_index
    embedding_dim = 300
    nb_words = min(vocab_size, len(word_index)) # How many words are there actually
    embedding_matrix = np.zeros((nb_words, embedding_dim))
    # The vectors need to be in the same position as their index. 
    # Meaning a word with token 1 needs to be in the second row (rows start with zero) and so on
    # Loop over all words in the word index
    for word, i in word_index.items():
        # If we are above the amount of words we want to use we do nothing
        if i >= vocab_size: 
            continue
        # Get the embedding vector for the word
        embedding_vector = embeddings_index.get(word)
        # If there is an embedding vector, put it in the embedding matrix
        if embedding_vector is not None: 
            embedding_matrix[i] = embedding_vector
    return train, test, max_length, embedding_matrix

def model_settings(length,vocabSize,embeddingMatrix,outputnum):
        embedding_dim = 300
        model = Sequential()
        model.add(Embedding(vocab_size, embedding_dim, input_length=length, weights = [embedding_matrix], 
                                trainable = False))
        model.add(Conv1D(200,3,padding='valid',activation='relu',strides=1))        
        # we use max pooling:
        model.add(GlobalMaxPooling1D())
        # We add a vanilla hidden layer:
        model.add(Dense(250))
        model.add(Dropout(0.2))
        model.add(Dense(outputnum, activation='softmax'))
        model.summary()
        return model

def fit_evaluate(model,Xtrain, ytrain,Xtest,ytest):
    EPOCHS = 10
    BATCH_SIZE = 100
    #set early stopping criteria
    pat = 5 #this is the number of epochs with no improvment after which the training will stop
    early_stopping = EarlyStopping(monitor='val_loss', patience=pat, verbose=1)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[categorical_accuracy])
    result = model.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=BATCH_SIZE, 
                        callbacks=[early_stopping], 
              verbose=1, validation_split=0.1)
    score = model.evaluate(Xtest, ytest, batch_size=BATCH_SIZE)
    return result,score

# %%
vocab_size = len(tfidfconverter.get_feature_names())
KFoldTrainResults = []
KFoldTestResults  = []
for i in testSize:
    print("------ "+str(i)+" testing size ------\n")
    Xtrain, Xtest, ytrain , ytest = train_test_split(df['description'].apply(str), labels, test_size= i, random_state = 42)
    categoricalLabel = to_categorical(ytrain)
    categoricalTestLabel = to_categorical(ytest)
    train, test, max_length, embedding_matrix =  tokenizer_and_pad_sequence(Xtrain,Xtest,vocab_size,embeddings_index)
    model = model_settings(max_length,vocab_size,embedding_matrix,len(np.unique(ytrain)))
    result,score = fit_evaluate(model,train,categoricalLabel,test,categoricalTestLabel)
    KFoldTrainResults.append(result)
    KFoldTestResults.append(score)
# Out:
# ------ 0.5 testing size ------
# WARNING: Logging before flag parsing goes to stderr.
# W0803 00:54:19.777822 4505228736 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0803 00:54:19.818325 4505228736 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0803 00:54:19.821165 4505228736 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0803 00:54:19.839443 4505228736 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0803 00:54:19.857939 4505228736 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0803 00:54:20.102016 4505228736 deprecation.py:506] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0803 00:54:20.190015 4505228736 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0803 00:54:20.245825 4505228736 deprecation.py:323] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 517, 300)          3333900
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 515, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 12843 samples, validate on 1427 samples
# Epoch 1/10
# 12843/12843 [==============================] - 65s 5ms/step - loss: 0.0764 - categorical_accuracy: 0.8805 - val_loss: 0.0270 - val_categorical_accuracy: 0.9580
# Epoch 2/10
# 12843/12843 [==============================] - 61s 5ms/step - loss: 0.0197 - categorical_accuracy: 0.9732 - val_loss: 0.0225 - val_categorical_accuracy: 0.9643
# Epoch 3/10
# 12843/12843 [==============================] - 61s 5ms/step - loss: 0.0082 - categorical_accuracy: 0.9897 - val_loss: 0.0172 - val_categorical_accuracy: 0.9755
# Epoch 4/10
# 12843/12843 [==============================] - 60s 5ms/step - loss: 0.0041 - categorical_accuracy: 0.9963 - val_loss: 0.0201 - val_categorical_accuracy: 0.9720
# Epoch 5/10
# 12843/12843 [==============================] - 33s 3ms/step - loss: 0.0026 - categorical_accuracy: 0.9978 - val_loss: 0.0169 - val_categorical_accuracy: 0.9776
# Epoch 6/10
# 12843/12843 [==============================] - 33s 3ms/step - loss: 0.0023 - categorical_accuracy: 0.9979 - val_loss: 0.0223 - val_categorical_accuracy: 0.9720
# Epoch 7/10
# 12843/12843 [==============================] - 33s 3ms/step - loss: 0.0019 - categorical_accuracy: 0.9987 - val_loss: 0.0203 - val_categorical_accuracy: 0.9741
# Epoch 8/10
# 12843/12843 [==============================] - 33s 3ms/step - loss: 0.0027 - categorical_accuracy: 0.9984 - val_loss: 0.0202 - val_categorical_accuracy: 0.9727
# Epoch 9/10
# 12843/12843 [==============================] - 33s 3ms/step - loss: 0.0020 - categorical_accuracy: 0.9988 - val_loss: 0.0232 - val_categorical_accuracy: 0.9741
# Epoch 10/10
# 12843/12843 [==============================] - 33s 3ms/step - loss: 0.0018 - categorical_accuracy: 0.9990 - val_loss: 0.0207 - val_categorical_accuracy: 0.9748
# Epoch 00010: early stopping
# 14270/14270 [==============================] - 15s 1ms/step
# ------ 0.3333333333333333 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 529, 300)          3333900
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 527, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 200)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 17123 samples, validate on 1903 samples
# Epoch 1/10
# 17123/17123 [==============================] - 46s 3ms/step - loss: 0.0670 - categorical_accuracy: 0.8974 - val_loss: 0.0255 - val_categorical_accuracy: 0.9595
# Epoch 2/10
# 17123/17123 [==============================] - 45s 3ms/step - loss: 0.0170 - categorical_accuracy: 0.9766 - val_loss: 0.0195 - val_categorical_accuracy: 0.9706
# Epoch 3/10
# 17123/17123 [==============================] - 45s 3ms/step - loss: 0.0082 - categorical_accuracy: 0.9893 - val_loss: 0.0193 - val_categorical_accuracy: 0.9716
# Epoch 4/10
# 17123/17123 [==============================] - 45s 3ms/step - loss: 0.0049 - categorical_accuracy: 0.9947 - val_loss: 0.0181 - val_categorical_accuracy: 0.9758
# Epoch 5/10
# 17123/17123 [==============================] - 45s 3ms/step - loss: 0.0037 - categorical_accuracy: 0.9960 - val_loss: 0.0184 - val_categorical_accuracy: 0.9753
# Epoch 6/10
# 17123/17123 [==============================] - 44s 3ms/step - loss: 0.0028 - categorical_accuracy: 0.9974 - val_loss: 0.0237 - val_categorical_accuracy: 0.9732
# Epoch 7/10
# 17123/17123 [==============================] - 45s 3ms/step - loss: 0.0036 - categorical_accuracy: 0.9971 - val_loss: 0.0222 - val_categorical_accuracy: 0.9743
# Epoch 8/10
# 17123/17123 [==============================] - 45s 3ms/step - loss: 0.0034 - categorical_accuracy: 0.9970 - val_loss: 0.0251 - val_categorical_accuracy: 0.9721
# Epoch 9/10
# 17123/17123 [==============================] - 44s 3ms/step - loss: 0.0032 - categorical_accuracy: 0.9970 - val_loss: 0.0440 - val_categorical_accuracy: 0.9532
# Epoch 00009: early stopping
# 9514/9514 [==============================] - 10s 1ms/step
# ------ 0.25 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 530, 300)          3333900
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 528, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 200)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 19264 samples, validate on 2141 samples
# Epoch 1/10
# 19264/19264 [==============================] - 50s 3ms/step - loss: 0.0601 - categorical_accuracy: 0.9089 - val_loss: 0.0232 - val_categorical_accuracy: 0.9650
# Epoch 2/10
# 19264/19264 [==============================] - 67s 3ms/step - loss: 0.0163 - categorical_accuracy: 0.9782 - val_loss: 0.0192 - val_categorical_accuracy: 0.9780
# Epoch 3/10
# 19264/19264 [==============================] - 87s 5ms/step - loss: 0.0081 - categorical_accuracy: 0.9896 - val_loss: 0.0159 - val_categorical_accuracy: 0.9766
# Epoch 4/10
# 19264/19264 [==============================] - 87s 5ms/step - loss: 0.0043 - categorical_accuracy: 0.9953 - val_loss: 0.0151 - val_categorical_accuracy: 0.9818
# Epoch 5/10
# 19264/19264 [==============================] - 88s 5ms/step - loss: 0.0039 - categorical_accuracy: 0.9958 - val_loss: 0.0220 - val_categorical_accuracy: 0.9668
# Epoch 6/10
# 19264/19264 [==============================] - 88s 5ms/step - loss: 0.0040 - categorical_accuracy: 0.9952 - val_loss: 0.0173 - val_categorical_accuracy: 0.9832
# Epoch 7/10
# 19264/19264 [==============================] - 87s 5ms/step - loss: 0.0031 - categorical_accuracy: 0.9967 - val_loss: 0.0203 - val_categorical_accuracy: 0.9813
# Epoch 8/10
# 19264/19264 [==============================] - 87s 5ms/step - loss: 0.0035 - categorical_accuracy: 0.9965 - val_loss: 0.0232 - val_categorical_accuracy: 0.9766
# Epoch 9/10
# 19264/19264 [==============================] - 87s 4ms/step - loss: 0.0033 - categorical_accuracy: 0.9970 - val_loss: 0.0255 - val_categorical_accuracy: 0.9729
# Epoch 00009: early stopping
# 7135/7135 [==============================] - 13s 2ms/step
# ------ 0.2 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 525, 300)          3333900
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 523, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 200)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 20548 samples, validate on 2284 samples
# Epoch 1/10
# 20548/20548 [==============================] - 95s 5ms/step - loss: 0.0622 - categorical_accuracy: 0.9082 - val_loss: 0.0246 - val_categorical_accuracy: 0.9619
# Epoch 2/10
# 20548/20548 [==============================] - 92s 4ms/step - loss: 0.0158 - categorical_accuracy: 0.9787 - val_loss: 0.0154 - val_categorical_accuracy: 0.9794
# Epoch 3/10
# 20548/20548 [==============================] - 90s 4ms/step - loss: 0.0081 - categorical_accuracy: 0.9895 - val_loss: 0.0198 - val_categorical_accuracy: 0.9729
# Epoch 4/10
# 20548/20548 [==============================] - 92s 4ms/step - loss: 0.0046 - categorical_accuracy: 0.9943 - val_loss: 0.0190 - val_categorical_accuracy: 0.9772
# Epoch 5/10
# 20548/20548 [==============================] - 91s 4ms/step - loss: 0.0039 - categorical_accuracy: 0.9962 - val_loss: 0.0209 - val_categorical_accuracy: 0.9750
# Epoch 6/10
# 20548/20548 [==============================] - 91s 4ms/step - loss: 0.0037 - categorical_accuracy: 0.9965 - val_loss: 0.0229 - val_categorical_accuracy: 0.9729
# Epoch 7/10
# 20548/20548 [==============================] - 91s 4ms/step - loss: 0.0029 - categorical_accuracy: 0.9979 - val_loss: 0.0222 - val_categorical_accuracy: 0.9772
# Epoch 00007: early stopping
# 5708/5708 [==============================] - 10s 2ms/step
# ------ 0.1 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 526, 300)          3333900
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 524, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 200)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 9)                 2259
# =================================================================
# Total params: 3,566,609
# Trainable params: 232,709
# Non-trainable params: 3,333,900
# _________________________________________________________________
# Train on 23117 samples, validate on 2569 samples
# Epoch 1/10
# 23117/23117 [==============================] - 106s 5ms/step - loss: 0.0584 - categorical_accuracy: 0.9134 - val_loss: 0.0186 - val_categorical_accuracy: 0.9724
# Epoch 2/10
# 23117/23117 [==============================] - 104s 5ms/step - loss: 0.0156 - categorical_accuracy: 0.9792 - val_loss: 0.0183 - val_categorical_accuracy: 0.9696
# Epoch 3/10
# 23117/23117 [==============================] - 104s 4ms/step - loss: 0.0084 - categorical_accuracy: 0.9891 - val_loss: 0.0210 - val_categorical_accuracy: 0.9646
# Epoch 4/10
# 23117/23117 [==============================] - 103s 4ms/step - loss: 0.0142 - categorical_accuracy: 0.9888 - val_loss: 0.0231 - val_categorical_accuracy: 0.9743
# Epoch 5/10
# 23117/23117 [==============================] - 102s 4ms/step - loss: 0.0095 - categorical_accuracy: 0.9933 - val_loss: 0.0185 - val_categorical_accuracy: 0.9805
# Epoch 6/10
# 23117/23117 [==============================] - 104s 4ms/step - loss: 0.0031 - categorical_accuracy: 0.9971 - val_loss: 0.0187 - val_categorical_accuracy: 0.9774
# Epoch 7/10
# 23117/23117 [==============================] - 103s 4ms/step - loss: 0.0034 - categorical_accuracy: 0.9967 - val_loss: 0.0201 - val_categorical_accuracy: 0.9774
# Epoch 00007: early stopping
# 2854/2854 [==============================] - 5s 2ms/step

# %%
fig, (ax,ax2) = plt.subplots(2, 1,figsize=(5,10))
for ele in KFoldTrainResults:
    currentTestsize = testSize[KFoldTrainResults.index(ele)]
    ax.plot(ele.history['categorical_accuracy'],label= str(round(1-currentTestsize,2))+" testing size")

    ax.legend()
ax.set_title('Categorical Accuracy Accuracy')
ax.set_xlabel("Epoch")
ax.set_ylabel("Validation categoryical accuracy")

for ele in KFoldTrainResults:
    currentTestsize = testSize[KFoldTrainResults.index(ele)]
    ax2.plot(ele.history['val_categorical_accuracy'],label= str(round(1-currentTestsize,2))+" testing size")
    ax2.legend()
ax2.set_title('Validation categoryical accuracy')
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Validation categoryical accuracy")

fig.savefig("CombineCNNsTrainCrossValidation.png", bbox_inches='tight')

# %%
fig, (ax1,ax3) = plt.subplots(2, 1,figsize=(5,10))
fig.subplots_adjust(hspace=0.5)
testSize = [ 1/ele for ele in K ]
ytrainTimeNBC = [ ele['fit_time'] for ele in NBCReport]
ytrainTimeSVC = [ ele['fit_time'] for ele in SVCReport]
ytestTimeNBC = [ ele['score_time'] for ele in NBCReport]
ytestTimeSVC = [ ele['score_time'] for ele in SVCReport]
yAccCNNs = [ele[1] for ele in KFoldTestResults]
yAccNBC = [ ele['test_accuracy'] for ele in NBCReport]
yAccSVC = [ ele['test_accuracy'] for ele in SVCReport]
line1, = ax1.plot(testSize, ytrainTimeNBC, color="tab:blue", label = "CNBC Training" )
line2, = ax1.plot(testSize, ytrainTimeSVC, color="tab:orange", label = "SVC Training" )
line1.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break
line2.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break

ax1.set_title('Training and Testing Time')
ax1.set_xlabel("Size of testing set")
ax1.set_ylabel("Training time (us)")
step1 = (max(ytrainTimeSVC) - min(ytrainTimeSVC))/len(ytrainTimeSVC)
ax1.yaxis.set_ticks(np.arange(0,max(ytrainTimeSVC),step1))
ax1.xaxis.set_ticks(np.arange(0,1,0.1))

# ax1.grid()
ax1.legend(loc=4)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(testSize, ytestTimeNBC, color="tab:blue", label = "CNBC Testing" )
ax2.plot(testSize, ytestTimeSVC, color="tab:orange", label = "SVC Testing" )
ax2.set_ylabel("Testing time (us)")
step2 = (max(ytestTimeSVC) - min(ytestTimeSVC))/len(ytestTimeSVC)
ax2.yaxis.set_ticks(np.arange(0,max(ytestTimeSVC),step2))
# ax2.grid()
ax2.legend(loc=1)

ax3.plot(testSize, yAccNBC, color="tab:blue", label = "CNBC" )
ax3.plot(testSize, yAccSVC, color="tab:orange", label = "SVC" )
ax3.plot(testSize, yAccCNNs, color="tab:red", label = "CNNs" )
ax3.set_title('Accuracy')
ax3.set_xlabel("Size of testing set")
ax3.set_ylabel("Accuracy")

ax3.grid()
ax3.legend()

fig.savefig("CombineCrossValidation.png", bbox_inches='tight')

print(K[np.argmax(yAccSVC)])
print(K[np.argmax(yAccCNNs)])
# Out:
# 5
# 2
