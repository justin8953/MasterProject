# %%
import pandas as pd 
import numpy as np
import os 
import json
from math import ceil, floor

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,chi2

from sklearn.preprocessing import LabelEncoder,scale
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.naive_bayes import ComplementNB
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.utils.multiclass import unique_labels

from sklearn.pipeline import Pipeline
from sklearn.externals import joblib

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 11})

import re
import nltk
from nltk.corpus import stopwords


from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Activation, Conv1D, Dense, Embedding, Flatten, Input, Dropout, GlobalMaxPooling1D
from keras.metrics import categorical_accuracy
from keras.callbacks import  EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;-]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))
Number_RE = re.compile('[*^0-9]')
Bad_underline = re.compile('[*_*]')
RemoveTag = re.compile('&lt;|br&gt;|b&gt;|ul&gt;|li&gt;')

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = RemoveTag.sub('',text)
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = Number_RE.sub(' ', text) # replace Number symbols by space in text
    text = Bad_underline.sub(' ', text) # replace Underline symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text
RemoveLastSpace = re.compile(' $')

def clean_text_category(text):
    text = RemoveLastSpace.sub('',text)
    return text

# %%
def classNumberThreshold(arr):
    dropCategory = []

    for key,value in arr.items():
        if(value<=30):
            dropCategory.append(key)
    return dropCategory

# %%
df = pd.read_csv('../walmartNewData.csv')

# %%
df = df[pd.notnull(df['longDescription'])]
df.longDescription = df.longDescription.apply(clean_text)
df = df[pd.notnull(df['itemId'])]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117423 entries, 0 to 117597
# Data columns (total 10 columns):
# productName         117416 non-null object
# shortDescription    117269 non-null object
# longDescription     117423 non-null object
# itemId              117423 non-null int64
# category            117423 non-null int64
# subcategory         117423 non-null int64
# sub2category        117423 non-null int64
# categoryName        117423 non-null object
# subcategoryName     117423 non-null object
# sub2categoryName    117423 non-null object
# dtypes: int64(4), object(6)
# memory usage: 9.9+ MB

# %%
le = LabelEncoder()
le.fit(df.category)
target = le.classes_
labels = le.transform(df.category)

le.fit(df.subcategory)
subtarget = le.classes_
sublabels = le.transform(df.subcategory)

# %%
targeName = [ np.unique(df[df['category']==ele]['categoryName'])[0] for ele in target]
subtargeName =  [ np.unique(df[df['subcategory']==ele]['subcategoryName'])[0] for ele in subtarget]

# %%
tfidfconverter = TfidfVectorizer(min_df=5, max_df=0.7)
X = tfidfconverter.fit_transform(df.longDescription)
featureNames = tfidfconverter.get_feature_names()

# %%
X_train, X_test, y_train_info, y_test_info = train_test_split(X, pd.DataFrame({'index':df.index, 'label':labels}), 
                                                    test_size=0.1, random_state = 27)

# %%
y_train = y_train_info.label
y_test = y_test_info.label

# %%
model = ComplementNB()
model.fit(X_train,y_train)
# Out:
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=True, norm=False)

# %%
classWithInfluence = {}

coef = model.coef_
coef = scale(coef)

coefTotalSize = coef.shape[0]*coef.shape[1]
coef1DArr = coef.reshape(coefTotalSize,1)
Max = ceil(max(coef1DArr[0]))
Min = floor(min(coef1DArr[0]))

for index in range(0,len(coef)):
    normalisedCoef = [round((ele-Min)/(Max-Min),2) for ele in coef[index]]
    name = featureNames
    classWithInfluence[targeName[index]] = list(zip(name,normalisedCoef))
            
Top10InflunceFeature = {}
for key, value in classWithInfluence.items():
    Top10InflunceFeature[key] = sorted(value, key=lambda x: x[1], reverse=True)[:10]

with open('Walmart/CompanyTopFeatureByClassNBC.json', 'w') as json_file:
    json.dump(Top10InflunceFeature, json_file, indent=2)

# %%
BestSize  = [ele for ele in range(100, len(featureNames), 100) ]
Models = []
Scores = []
SelectModels  = []
for ele in range(100, len(featureNames), 100):
    print("--- Best "+ str(ele) + " features \n")
    selectBest = SelectKBest(chi2, k= ele)
    model = ComplementNB()
    K_best_NBC = Pipeline([('SelectBest', selectBest), ('CNBC', model)])
    K_best_NBC.fit(X_train,y_train)
    score = K_best_NBC.score(X_test,y_test)
    Models.append(K_best_NBC)
    Scores.append(score)

bestModel = Models[np.argmax(Scores)]
bestSize = BestSize[np.argmax(Scores)]

# save the model to disk
filename = 'Walmart/'+str(bestSize)+'BestNBC.sav'
joblib.dump(bestModel, filename)



yConfidence = bestModel.predict_proba(X_test)

yPred = bestModel.predict(X_test)
# Out:
# --- Best 100 features
#
# --- Best 200 features
#
# --- Best 300 features
#
# --- Best 400 features
#
# --- Best 500 features
#
# --- Best 600 features
#
# --- Best 700 features
#
# --- Best 800 features
#
# --- Best 900 features
#
# --- Best 1000 features
#
# --- Best 1100 features
#
# --- Best 1200 features
#
# --- Best 1300 features
#
# --- Best 1400 features
#
# --- Best 1500 features
#
# --- Best 1600 features
#
# --- Best 1700 features
#
# --- Best 1800 features
#
# --- Best 1900 features
#
# --- Best 2000 features
#
# --- Best 2100 features
#
# --- Best 2200 features
#
# --- Best 2300 features
#
# --- Best 2400 features
#
# --- Best 2500 features
#
# --- Best 2600 features
#
# --- Best 2700 features
#
# --- Best 2800 features
#
# --- Best 2900 features
#
# --- Best 3000 features
#
# --- Best 3100 features
#
# --- Best 3200 features
#
# --- Best 3300 features
#
# --- Best 3400 features
#
# --- Best 3500 features
#
# --- Best 3600 features
#
# --- Best 3700 features
#
# --- Best 3800 features
#
# --- Best 3900 features
#
# --- Best 4000 features
#
# --- Best 4100 features
#
# --- Best 4200 features
#
# --- Best 4300 features
#
# --- Best 4400 features
#
# --- Best 4500 features
#
# --- Best 4600 features
#
# --- Best 4700 features
#
# --- Best 4800 features
#
# --- Best 4900 features
#
# --- Best 5000 features
#
# --- Best 5100 features
#
# --- Best 5200 features
#
# --- Best 5300 features
#
# --- Best 5400 features
#
# --- Best 5500 features
#
# --- Best 5600 features
#
# --- Best 5700 features
#
# --- Best 5800 features
#
# --- Best 5900 features
#
# --- Best 6000 features
#
# --- Best 6100 features
#
# --- Best 6200 features
#
# --- Best 6300 features
#
# --- Best 6400 features
#
# --- Best 6500 features
#
# --- Best 6600 features
#
# --- Best 6700 features
#
# --- Best 6800 features
#
# --- Best 6900 features
#
# --- Best 7000 features
#
# --- Best 7100 features
#
# --- Best 7200 features
#
# --- Best 7300 features
#
# --- Best 7400 features
#
# --- Best 7500 features
#
# --- Best 7600 features
#
# --- Best 7700 features
#
# --- Best 7800 features
#
# --- Best 7900 features
#
# --- Best 8000 features
#
# --- Best 8100 features
#
# --- Best 8200 features
#
# --- Best 8300 features
#
# --- Best 8400 features
#
# --- Best 8500 features
#
# --- Best 8600 features
#
# --- Best 8700 features
#
# --- Best 8800 features
#
# --- Best 8900 features
#
# --- Best 9000 features
#
# --- Best 9100 features
#
# --- Best 9200 features
#
# --- Best 9300 features
#
# --- Best 9400 features
#
# --- Best 9500 features
#
# --- Best 9600 features
#
# --- Best 9700 features
#
# --- Best 9800 features
#
# --- Best 9900 features
#
# --- Best 10000 features
#
# --- Best 10100 features
#
# --- Best 10200 features
#
# --- Best 10300 features
#
# --- Best 10400 features
#
# --- Best 10500 features
#
# --- Best 10600 features
#
# --- Best 10700 features
#
# --- Best 10800 features
#
# --- Best 10900 features
#
# --- Best 11000 features
#
# --- Best 11100 features
#
# --- Best 11200 features
#
# --- Best 11300 features
#
# --- Best 11400 features
#
# --- Best 11500 features
#
# --- Best 11600 features
#
# --- Best 11700 features
#
# --- Best 11800 features
#
# --- Best 11900 features
#
# --- Best 12000 features
#
# --- Best 12100 features
#
# --- Best 12200 features
#
# --- Best 12300 features
#
# --- Best 12400 features
#
# --- Best 12500 features
#
# --- Best 12600 features
#
# --- Best 12700 features
#
# --- Best 12800 features
#
# --- Best 12900 features
#
# --- Best 13000 features
#
# --- Best 13100 features
#
# --- Best 13200 features
#
# --- Best 13300 features
#
# --- Best 13400 features
#
# --- Best 13500 features
#
# --- Best 13600 features
#
# --- Best 13700 features
#
# --- Best 13800 features
#
# --- Best 13900 features
#
# --- Best 14000 features
#
# --- Best 14100 features
#
# --- Best 14200 features
#
# --- Best 14300 features
#
# --- Best 14400 features
#
# --- Best 14500 features
#
# --- Best 14600 features
#
# --- Best 14700 features
#
# --- Best 14800 features
#
# --- Best 14900 features
#
# --- Best 15000 features
#
# --- Best 15100 features
#
# --- Best 15200 features
#
# --- Best 15300 features
#
# --- Best 15400 features
#
# --- Best 15500 features
#
# --- Best 15600 features
#
# --- Best 15700 features
#
# --- Best 15800 features
#
# --- Best 15900 features
#
# --- Best 16000 features
#
# --- Best 16100 features
#
# --- Best 16200 features
#
# --- Best 16300 features
#
# --- Best 16400 features
#
# --- Best 16500 features
#
# --- Best 16600 features
#
# --- Best 16700 features
#
# --- Best 16800 features
#
# --- Best 16900 features
#
# --- Best 17000 features
#
# --- Best 17100 features
#
# --- Best 17200 features
#
# --- Best 17300 features
#
# --- Best 17400 features
#
# --- Best 17500 features
#
# --- Best 17600 features
#
# --- Best 17700 features
#
# --- Best 17800 features
#
# --- Best 17900 features
#
# --- Best 18000 features
#
# --- Best 18100 features
#
# --- Best 18200 features
#
# --- Best 18300 features
#
# --- Best 18400 features
#
# --- Best 18500 features
#
# --- Best 18600 features
#
# --- Best 18700 features
#
# --- Best 18800 features
#
# --- Best 18900 features
#
# --- Best 19000 features
#
# --- Best 19100 features
#
# --- Best 19200 features
#
# --- Best 19300 features
#
# --- Best 19400 features
#
# --- Best 19500 features
#
# --- Best 19600 features
#
# --- Best 19700 features
#
# --- Best 19800 features
#
# --- Best 19900 features
#
# --- Best 20000 features
#
# --- Best 20100 features
#
# --- Best 20200 features
#
# --- Best 20300 features
#
# --- Best 20400 features
#
# --- Best 20500 features
#
# --- Best 20600 features
#
# --- Best 20700 features
#
# --- Best 20800 features
#
# --- Best 20900 features
#
# --- Best 21000 features
#
# --- Best 21100 features
#
# --- Best 21200 features
#
# --- Best 21300 features
#
# --- Best 21400 features
#
# --- Best 21500 features
#
# --- Best 21600 features
#
# --- Best 21700 features
#
# --- Best 21800 features
#
# --- Best 21900 features
#
# --- Best 22000 features
#
# --- Best 22100 features
#
# --- Best 22200 features
#
# --- Best 22300 features
#
# --- Best 22400 features
#
# --- Best 22500 features
#
# --- Best 22600 features
#
# --- Best 22700 features
#
# --- Best 22800 features
#
# --- Best 22900 features
#
# --- Best 23000 features
#
# --- Best 23100 features
#
# --- Best 23200 features
#
# --- Best 23300 features
#
# --- Best 23400 features
#
# --- Best 23500 features
#
# --- Best 23600 features
#
# --- Best 23700 features
#
# --- Best 23800 features
#
# --- Best 23900 features
#
# --- Best 24000 features
#
# --- Best 24100 features
#
# --- Best 24200 features
#
# --- Best 24300 features
#
# --- Best 24400 features
#
# --- Best 24500 features
#
# --- Best 24600 features
#
# --- Best 24700 features
#
# --- Best 24800 features
#
# --- Best 24900 features
#
# --- Best 25000 features
#
# --- Best 25100 features
#
# --- Best 25200 features
#
# --- Best 25300 features
#
# --- Best 25400 features
#
# --- Best 25500 features
#
# --- Best 25600 features
#
# --- Best 25700 features
#
# --- Best 25800 features
#
# --- Best 25900 features
#
# --- Best 26000 features
#
# --- Best 26100 features
#
# --- Best 26200 features
#
# --- Best 26300 features
#
# --- Best 26400 features
#
# --- Best 26500 features
#
# --- Best 26600 features
#
# --- Best 26700 features
#
# --- Best 26800 features
#
# --- Best 26900 features
#
# --- Best 27000 features
#
# --- Best 27100 features
#
# --- Best 27200 features
#
# --- Best 27300 features
#
# --- Best 27400 features
#
# --- Best 27500 features
#
# --- Best 27600 features
#
# --- Best 27700 features

# %%
targeName[y_test]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-5954434b16bb> in <module>
# ----> 1 targeName[y_test]
#
# TypeError: list indices must be integers or slices, not Series

# %%
totalConfidenceSize = yConfidence.shape[0]*yConfidence.shape[1]
Confidence1DArr = yConfidence.reshape(totalConfidenceSize,1)
Max = ceil(max(Confidence1DArr)[0])
Min = floor(min(Confidence1DArr)[0])
NormalisedConfid = [round((max(ele)-Min)/(Max-Min),2) for ele in yConfidence]
productID = [ df[df.index==ele]['itemId'].values[0] for ele in y_test_info['index'] ]
ProductDescription =[ df[df.index==ele]['longDescription'].values[0] for ele in y_test_info['index'] ]
NBCResult = pd.DataFrame({'id':productID,'description':ProductDescription,
                         'trueClass': y_test,'trueClassNaem':[targeName[ele] for ele in y_test ],
                         'predictClass':yPred,'predictClassName':[targeName[ele] for ele in yPred ],
                         'Confidence':NormalisedConfid})
NBCResult.to_csv("Walmart/NBCResults.csv",index=False,compression=None)

# %%
def draw_confidenceReport(data):
    num = [ ele*0.01 for ele in range(20,81,2)]
    totalitems = []
    correct = []
    incorrect = []
    for ele in num:
        Threshold = data[data['Confidence']>ele]
        correct.append(len(Threshold[Threshold['trueClass']==Threshold['predictClass']].index))
        incorrect.append(len(Threshold[Threshold['trueClass']!=Threshold['predictClass']].index))
        totalitems.append(len(Threshold.index))
    
    ClassfiedProportion = [ ele/len(data.index) for ele in totalitems]
    
    Acc =[]
    for ele in zip(correct,totalitems):
        if (ele[1]==0):
            Acc.append(0)
        else:
            Acc.append(ele[0]/ele[1])

    fig,ax  = plt.subplots()
    
    color = 'tab:blue'
    ax.scatter(num,ClassfiedProportion,label="Proportion classified",color=color)
    ax.set_xlabel("Confidence Score")
    ax.set_ylabel("Proportion classified", color=color)
    ax.xaxis.set_ticks(np.arange(0,1.1,0.1))
    ax.yaxis.set_ticks(np.arange(0,1.1,0.1))
    ax.tick_params(axis='y', labelcolor=color)

    color = 'tab:red'

    ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

    ax2.scatter(num,Acc,label="Accuracy", color=color)
    ax2.set_ylabel("Accuracy", color=color)
    ax2.yaxis.set_ticks(np.arange(0,1.1,0.1))
    ax2.tick_params(axis='y', labelcolor=color)

    ax.grid()
    fig.savefig("Walmart/ConfidenceScoreReportNBC.png")

# %%
print(classification_report(y_test, yPred,target_names=targeName))
with open('Walmart/NBCReport.txt', 'w') as file:
    file.write(classification_report(y_test, yPred,target_names=targeName))
# Out:
#                          precision    recall  f1-score   support
#
#             Video Games       0.51      0.74      0.60        57
#       Party & Occasions       0.82      0.57      0.67       126
#                 Jewelry       0.86      0.97      0.91      1195
#                   Books       0.88      0.88      0.88      1031
#             Electronics       0.74      0.87      0.80       540
#                    Home       0.86      0.93      0.89      3006
#       Movies & TV Shows       0.87      0.76      0.81        17
#                   Music       1.00      0.07      0.13        29
#       Sports & Outdoors       0.82      0.49      0.62       269
#                    Toys       0.81      0.44      0.57       185
#                    Baby       1.00      0.30      0.46        20
#          Patio & Garden       0.72      0.15      0.25       117
#                Clothing       0.88      0.96      0.92      2272
#                    Pets       0.78      0.63      0.70        63
#                 Feature       0.00      0.00      0.00         2
#            Auto & Tires       0.79      0.87      0.83       767
#                    Food       0.81      0.86      0.83        96
#                  Health       0.94      0.54      0.68        56
#           Personal Care       0.92      0.88      0.90        83
#        Home Improvement       0.80      0.41      0.54       348
#                Seasonal       0.00      0.00      0.00        15
#                  Beauty       0.82      0.76      0.79       141
#             Cell Phones       0.82      0.91      0.87       396
#    Household Essentials       0.84      0.72      0.78       105
#                  Office       0.86      0.39      0.54       112
#    Arts Crafts & Sewing       0.77      0.68      0.72       533
#           Shop by Brand       0.67      0.07      0.13        82
#           Shop by Movie       0.00      0.00      0.00         6
#         Shop by TV Show       0.00      0.00      0.00         1
# Industrial & Scientific       0.81      0.55      0.66        38
#     Musical Instruments       0.00      0.00      0.00         5
#          Premium Beauty       0.76      0.83      0.79        30
#
#               micro avg       0.85      0.85      0.85     11743
#               macro avg       0.69      0.54      0.57     11743
#            weighted avg       0.84      0.85      0.83     11743
# /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
draw_confidenceReport(NBCResult)

# %%
cm = confusion_matrix(y_test, yPred)

# %%
fig, ax = plt.subplots(figsize=(10,10))
im =ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
classes = targeName
# We want to show all ticks...
ax.set(xticks=np.arange(cm.shape[1]),yticks=np.arange(cm.shape[0]),
       # ... and label them with the respective list entries
        xticklabels=classes, yticklabels=classes,ylabel='True label',xlabel='Predicted label')
# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
fmt = 'd'
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),ha="center", va="center", color="white" if cm[i, j] > thresh else "black")
fig.tight_layout()
fig.savefig("Walmart/NBCConfusionMatrix.png")

# %%
fig,ax  = plt.subplots()
ax.plot(BestSize,Scores,label="CNBC")
ax.set_xlabel("Number of best features")
ax.set_ylabel("Accuracy")
ax.legend()
ax.grid()
fig.savefig("Walmart/CNBCbestFeatureSize.png")
