# %%
import pandas as pd 
import numpy as np
import os 
import json
from math import ceil, floor

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,chi2

from sklearn.preprocessing import LabelEncoder,scale
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.naive_bayes import ComplementNB
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.utils.multiclass import unique_labels

from sklearn.pipeline import Pipeline
from sklearn.externals import joblib

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 11})

import re
import nltk
from nltk.corpus import stopwords


from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Activation, Conv1D, Dense, Embedding, Flatten, Input, Dropout, GlobalMaxPooling1D,MaxPooling1D,LSTM
from keras.metrics import categorical_accuracy
from keras.callbacks import  EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;-]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))
Number_RE = re.compile('[*^0-9]')
Bad_underline = re.compile('[*_*]')
RemoveTag = re.compile('&lt;|br&gt;|b&gt;|ul&gt;|li&gt;')

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = RemoveTag.sub('',text)
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = Number_RE.sub(' ', text) # replace Number symbols by space in text
    text = Bad_underline.sub(' ', text) # replace Underline symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text
RemoveLastSpace = re.compile(' $')

def clean_text_category(text):
    text = RemoveLastSpace.sub('',text)
    return text

# %%
def classNumberThreshold(arr):
    dropCategory = []

    for key,value in arr.items():
        if(value<=30):
            dropCategory.append(key)
    return dropCategory

# %%
df = pd.read_csv('../../example/fliptkart.csv')

# %%
df = df[pd.notnull(df['description'])]
df.description = df.description.apply(clean_text)
df = df[pd.notnull(df['category_main'])]
df = df[pd.notnull(df['pid'])]

# %%
dropCategoryCode  = classNumberThreshold(df.category_main.value_counts())
dropSubCategoryCode  = classNumberThreshold(df.category_sub1.value_counts())

for i in dropCategoryCode:
    df = df[df.category_main!=i]
    
for i in dropSubCategoryCode:
    df = df[df.category_sub1!=i]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17667 entries, 0 to 19997
# Data columns (total 8 columns):
# uniq_id          17667 non-null object
# product_url      17667 non-null object
# product_name     17667 non-null object
# pid              17667 non-null object
# description      17667 non-null object
# category_main    17667 non-null object
# category_sub1    17667 non-null object
# category_sub2    17667 non-null object
# dtypes: object(8)
# memory usage: 1.2+ MB

# %%
embedding_dim = 300 # We use 100 dimensional glove vectors
glove_dir = '../../glove.6B' # This is the folder with the dataset
embeddings_index = {} # We create a dictionary of word -> embedding
with open(os.path.join(glove_dir, 'glove.6B.300d.txt')) as f:
    for line in f:
        values = line.split()
        word = values[0] # The first value is the word, the rest are the values of the embedding
        embedding = np.asarray(values[1:], dtype='float32') # Load embedding
        embeddings_index[word] = embedding # Add embedding to our embedding dictionary
    print('Found {:,} word vectors in GloVe.'.format(len(embeddings_index)))
# Out:
# Found 400,000 word vectors in GloVe.

# %%
le = LabelEncoder()
le.fit(df.category_main)
target = le.classes_
labels = le.transform(df.category_main)

le.fit(df.category_sub1)
subtarget = le.classes_
sublabels = le.transform(df.category_sub1)

# %%
X_train, X_test, y_train_info, y_test_info = train_test_split(df.description, pd.DataFrame({'index':df.index, 'label':labels}), 
                                                    test_size=0.1, random_state = 27)

# %%
y_train = y_train_info.label
y_test = y_test_info.label

# %%
tfidfconverter = TfidfVectorizer(min_df=5, max_df=0.7)
X = tfidfconverter.fit_transform(df.description)
vocab_size = len(tfidfconverter.get_feature_names())

# %%
def tokenizer_and_pad_sequence (Xtrain,Xtest,vocab_size,embeddings_index):
    tokenizer = Tokenizer(num_words=vocab_size) # Setup tokenizer
    tokenizer.fit_on_texts(Xtrain)
    
    sequences = tokenizer.texts_to_sequences(Xtrain)
    sequences_test = tokenizer.texts_to_sequences(Xtest)
    
    trainlengths = [len(ele) for ele in sequences]
    testlengths = [len(ele) for ele in sequences_test]
    max_length = min(max(trainlengths),max(testlengths))
    
    
    
    word_index = tokenizer.word_index
    embedding_dim = 300
    nb_words = min(vocab_size, len(word_index)) # How many words are there actually
    embedding_matrix = np.zeros((nb_words, embedding_dim))
    # The vectors need to be in the same position as their index. 
    # Meaning a word with token 1 needs to be in the second row (rows start with zero) and so on
    # Loop over all words in the word index
    for word, i in word_index.items():
        # If we are above the amount of words we want to use we do nothing
        if i >= vocab_size: 
            continue
        # Get the embedding vector for the word
        embedding_vector = embeddings_index.get(word)
        # If there is an embedding vector, put it in the embedding matrix
        if embedding_vector is not None: 
            embedding_matrix[i] = embedding_vector
    return sequences,sequences_test,max_length, embedding_matrix

def model_settings(length,vocabSize,embeddingMatrix,outputnum):
        embedding_dim = 300
        model = Sequential()
        model.add(Embedding(vocab_size, embedding_dim, input_length=length, weights = [embedding_matrix], 
                                trainable = False))
        model.add(Conv1D(200,3,padding='valid',activation='relu',strides=1))        
        # we use max pooling:
        model.add(GlobalMaxPooling1D())
        # We add a vanilla hidden layer:
        model.add(Dense(250))
        model.add(Dropout(0.2))
        model.add(Dense(outputnum, activation='softmax'))
        model.summary()
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[categorical_accuracy])
        return model
def model_settings2(length,vocabSize,embeddingMatrix,outputnum):
        embedding_dim = 300
        model = Sequential()
        model.add(Embedding(vocabSize, embedding_dim, input_length=length, weights = [embeddingMatrix], 
                                trainable = False))
        model.add(Dropout(0.25))
        model.add(Conv1D(128,5,padding='valid',activation='relu',strides=1))        
        # we use max pooling:
        model.add(MaxPooling1D(4))
        model.add(LSTM(70))
        model.add(Dropout(0.2))
        model.add(Dense(outputnum, activation='softmax'))
        model.summary()
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[categorical_accuracy])
        return model

# %%
categoricalLabel = to_categorical(y_train)
categoricalTestLabel = to_categorical(y_test)

EPOCHS = 10
BATCH_SIZE = 100

#set early stopping criteria
pat = 5 #this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='val_loss', patience=pat, verbose=1)


sequences,sequences_test,max_length, embedding_matrix =  tokenizer_and_pad_sequence(X_train,X_test, vocab_size, embeddings_index)

Scores = []
Models = []
Scores2 = []
Models2 = []
Scores3 = []
Models3 = []
Lengths = [ele for ele in range(50, max_length, 100)]
for ele in range(50, max_length, 100):
    
    train = pad_sequences(sequences,maxlen= ele)
    test = pad_sequences(sequences_test,maxlen = ele)
    
    model = model_settings(ele, vocab_size, embedding_matrix, len(np.unique(y_train)))
    model2 = model_settings2(ele, vocab_size, embedding_matrix, len(np.unique(y_train)))
    model.fit(train, categoricalLabel, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping],  
                   verbose=1, validation_split=0.1)
    model2.fit(train, categoricalLabel, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping],  
                   verbose=1, validation_split=0.1)
    
    loss, score = model.evaluate(test, categoricalTestLabel, batch_size=BATCH_SIZE)
    loss2, score2 = model2.evaluate(test, categoricalTestLabel, batch_size=BATCH_SIZE)

    Scores.append(score)
    Models.append(model)
    Scores2.append(score2)
    Models2.append(model2)    
    
bestModelIndex = np.argmax(Scores)
bestLength = Lengths[bestModelIndex]
bestModel = Models[bestModelIndex]

bestModelIndex2 = np.argmax(Scores2)
bestLength2 = Lengths[bestModelIndex2]
bestModel2 = Models2[bestModelIndex2]


# save the model to disk
filename = 'Flipkart/'+str(bestLength)+'BestCNNs.sav'
joblib.dump(bestModel, filename)
filename2 = 'Flipkart/'+str(bestLength2)+'BestLayerCNNswithLSTM.sav'
joblib.dump(bestModel2, filename2)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0803 12:44:56.729449 4520846784 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0803 12:44:56.750313 4520846784 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0803 12:44:56.753251 4520846784 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0803 12:44:56.763621 4520846784 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0803 12:44:56.764559 4520846784 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0803 12:44:56.864422 4520846784 deprecation.py:506] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0803 12:44:56.891757 4520846784 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0803 12:44:56.917509 4520846784 deprecation.py:323] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0803 12:44:57.055924 4520846784 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 50, 300)           1759800
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 48, 200)           180200
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 22)                5522
# =================================================================
# Total params: 1,995,772
# Trainable params: 235,972
# Non-trainable params: 1,759,800
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 50, 300)           1759800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50, 300)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 128)           192128
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 11, 128)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 70)                55720
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 70)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 22)                1562
# =================================================================
# Total params: 2,009,210
# Trainable params: 249,410
# Non-trainable params: 1,759,800
# _________________________________________________________________
# Train on 14310 samples, validate on 1590 samples
# Epoch 1/10
# 14310/14310 [==============================] - 5s 346us/step - loss: 0.0328 - categorical_accuracy: 0.8753 - val_loss: 0.0120 - val_categorical_accuracy: 0.9516
# Epoch 2/10
# 14310/14310 [==============================] - 4s 292us/step - loss: 0.0065 - categorical_accuracy: 0.9776 - val_loss: 0.0085 - val_categorical_accuracy: 0.9667
# Epoch 3/10
# 14310/14310 [==============================] - 4s 305us/step - loss: 0.0032 - categorical_accuracy: 0.9894 - val_loss: 0.0084 - val_categorical_accuracy: 0.9736
# Epoch 4/10
# 14310/14310 [==============================] - 5s 332us/step - loss: 0.0022 - categorical_accuracy: 0.9929 - val_loss: 0.0100 - val_categorical_accuracy: 0.9692
# Epoch 5/10
# 14310/14310 [==============================] - 6s 385us/step - loss: 0.0017 - categorical_accuracy: 0.9946 - val_loss: 0.0085 - val_categorical_accuracy: 0.9730
# Epoch 6/10
# 14310/14310 [==============================] - 5s 384us/step - loss: 8.7275e-04 - categorical_accuracy: 0.9975 - val_loss: 0.0071 - val_categorical_accuracy: 0.9742
# Epoch 7/10
# 14310/14310 [==============================] - 5s 352us/step - loss: 0.0010 - categorical_accuracy: 0.9973 - val_loss: 0.0071 - val_categorical_accuracy: 0.9755
# Epoch 8/10
# 14310/14310 [==============================] - 5s 343us/step - loss: 0.0010 - categorical_accuracy: 0.9970 - val_loss: 0.0088 - val_categorical_accuracy: 0.9692
# Epoch 9/10
# 14310/14310 [==============================] - 5s 342us/step - loss: 0.0012 - categorical_accuracy: 0.9968 - val_loss: 0.0084 - val_categorical_accuracy: 0.9698
# Epoch 10/10
# 14310/14310 [==============================] - 5s 347us/step - loss: 0.0014 - categorical_accuracy: 0.9955 - val_loss: 0.0090 - val_categorical_accuracy: 0.9723
# Train on 14310 samples, validate on 1590 samples
# Epoch 1/10
# 14310/14310 [==============================] - 9s 647us/step - loss: 0.0500 - categorical_accuracy: 0.8086 - val_loss: 0.0216 - val_categorical_accuracy: 0.9170
# Epoch 2/10
# 14310/14310 [==============================] - 8s 581us/step - loss: 0.0154 - categorical_accuracy: 0.9477 - val_loss: 0.0154 - val_categorical_accuracy: 0.9428
# Epoch 3/10
# 14310/14310 [==============================] - 8s 568us/step - loss: 0.0096 - categorical_accuracy: 0.9670 - val_loss: 0.0127 - val_categorical_accuracy: 0.9547
# Epoch 4/10
# 14310/14310 [==============================] - 8s 587us/step - loss: 0.0074 - categorical_accuracy: 0.9738 - val_loss: 0.0110 - val_categorical_accuracy: 0.9597
# Epoch 5/10
# 14310/14310 [==============================] - 9s 595us/step - loss: 0.0051 - categorical_accuracy: 0.9834 - val_loss: 0.0092 - val_categorical_accuracy: 0.9654
# Epoch 6/10
# 14310/14310 [==============================] - 9s 656us/step - loss: 0.0039 - categorical_accuracy: 0.9871 - val_loss: 0.0090 - val_categorical_accuracy: 0.9679
# Epoch 7/10
# 14310/14310 [==============================] - 8s 588us/step - loss: 0.0033 - categorical_accuracy: 0.9889 - val_loss: 0.0087 - val_categorical_accuracy: 0.9673
# Epoch 8/10
# 14310/14310 [==============================] - 9s 649us/step - loss: 0.0026 - categorical_accuracy: 0.9908 - val_loss: 0.0097 - val_categorical_accuracy: 0.9679
# Epoch 9/10
# 14310/14310 [==============================] - 9s 633us/step - loss: 0.0022 - categorical_accuracy: 0.9929 - val_loss: 0.0090 - val_categorical_accuracy: 0.9717
# Epoch 10/10
# 14310/14310 [==============================] - 11s 753us/step - loss: 0.0021 - categorical_accuracy: 0.9932 - val_loss: 0.0084 - val_categorical_accuracy: 0.9704
# 1767/1767 [==============================] - 0s 183us/step
# 1767/1767 [==============================] - 0s 234us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 150, 300)          1759800
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 148, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 22)                5522
# =================================================================
# Total params: 1,995,772
# Trainable params: 235,972
# Non-trainable params: 1,759,800
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 150, 300)          1759800
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 150, 300)          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 146, 128)          192128
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 36, 128)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 70)                55720
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 70)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 22)                1562
# =================================================================
# Total params: 2,009,210
# Trainable params: 249,410
# Non-trainable params: 1,759,800
# _________________________________________________________________
# Train on 14310 samples, validate on 1590 samples
# Epoch 1/10
# 14310/14310 [==============================] - 16s 1ms/step - loss: 0.0313 - categorical_accuracy: 0.8824 - val_loss: 0.0106 - val_categorical_accuracy: 0.9585
# Epoch 2/10
# 14310/14310 [==============================] - 14s 992us/step - loss: 0.0063 - categorical_accuracy: 0.9783 - val_loss: 0.0069 - val_categorical_accuracy: 0.9711
# Epoch 3/10
# 14310/14310 [==============================] - 15s 1ms/step - loss: 0.0029 - categorical_accuracy: 0.9904 - val_loss: 0.0055 - val_categorical_accuracy: 0.9780
# Epoch 4/10
# 14310/14310 [==============================] - 19s 1ms/step - loss: 0.0019 - categorical_accuracy: 0.9940 - val_loss: 0.0080 - val_categorical_accuracy: 0.9736
# Epoch 5/10
# 14310/14310 [==============================] - 18s 1ms/step - loss: 0.0014 - categorical_accuracy: 0.9952 - val_loss: 0.0057 - val_categorical_accuracy: 0.9792
# Epoch 6/10
# 14310/14310 [==============================] - 15s 1ms/step - loss: 9.4354e-04 - categorical_accuracy: 0.9973 - val_loss: 0.0054 - val_categorical_accuracy: 0.9767
# Epoch 7/10
# 14310/14310 [==============================] - 15s 1ms/step - loss: 5.8800e-04 - categorical_accuracy: 0.9980 - val_loss: 0.0046 - val_categorical_accuracy: 0.9843
# Epoch 8/10
# 14310/14310 [==============================] - 15s 1ms/step - loss: 5.8205e-04 - categorical_accuracy: 0.9983 - val_loss: 0.0064 - val_categorical_accuracy: 0.9774
# Epoch 9/10
# 14310/14310 [==============================] - 15s 1ms/step - loss: 5.2189e-04 - categorical_accuracy: 0.9984 - val_loss: 0.0057 - val_categorical_accuracy: 0.9805
# Epoch 10/10
# 14310/14310 [==============================] - 15s 1ms/step - loss: 8.8783e-04 - categorical_accuracy: 0.9970 - val_loss: 0.0059 - val_categorical_accuracy: 0.9824
# Train on 14310 samples, validate on 1590 samples
# Epoch 1/10
# 14310/14310 [==============================] - 33s 2ms/step - loss: 0.0545 - categorical_accuracy: 0.7878 - val_loss: 0.0238 - val_categorical_accuracy: 0.9094
# Epoch 2/10
# 14310/14310 [==============================] - 36s 3ms/step - loss: 0.0171 - categorical_accuracy: 0.9413 - val_loss: 0.0151 - val_categorical_accuracy: 0.9453
# Epoch 3/10
# 14310/14310 [==============================] - 43s 3ms/step - loss: 0.0110 - categorical_accuracy: 0.9621 - val_loss: 0.0123 - val_categorical_accuracy: 0.9560
# Epoch 4/10
# 14310/14310 [==============================] - 38s 3ms/step - loss: 0.0083 - categorical_accuracy: 0.9714 - val_loss: 0.0095 - val_categorical_accuracy: 0.9654
# Epoch 5/10
# 14310/14310 [==============================] - 36s 3ms/step - loss: 0.0069 - categorical_accuracy: 0.9762 - val_loss: 0.0097 - val_categorical_accuracy: 0.9654
# Epoch 6/10
# 14310/14310 [==============================] - 36s 3ms/step - loss: 0.0051 - categorical_accuracy: 0.9822 - val_loss: 0.0081 - val_categorical_accuracy: 0.9673
# Epoch 7/10
# 14310/14310 [==============================] - 36s 3ms/step - loss: 0.0039 - categorical_accuracy: 0.9869 - val_loss: 0.0073 - val_categorical_accuracy: 0.9704
# Epoch 8/10
# 14310/14310 [==============================] - 36s 3ms/step - loss: 0.0046 - categorical_accuracy: 0.9851 - val_loss: 0.0075 - val_categorical_accuracy: 0.9730
# Epoch 9/10
# 14310/14310 [==============================] - 36s 3ms/step - loss: 0.0036 - categorical_accuracy: 0.9875 - val_loss: 0.0073 - val_categorical_accuracy: 0.9711
# Epoch 10/10
# 14310/14310 [==============================] - 33s 2ms/step - loss: 0.0026 - categorical_accuracy: 0.9909 - val_loss: 0.0065 - val_categorical_accuracy: 0.9786
# 1767/1767 [==============================] - 1s 584us/step
# 1767/1767 [==============================] - 2s 878us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 250, 300)          1759800
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 248, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 200)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 22)                5522
# =================================================================
# Total params: 1,995,772
# Trainable params: 235,972
# Non-trainable params: 1,759,800
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 250, 300)          1759800
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 250, 300)          0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 246, 128)          192128
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 61, 128)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 70)                55720
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 70)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 22)                1562
# =================================================================
# Total params: 2,009,210
# Trainable params: 249,410
# Non-trainable params: 1,759,800
# _________________________________________________________________
# Train on 14310 samples, validate on 1590 samples
# Epoch 1/10
# 14310/14310 [==============================] - 40s 3ms/step - loss: 0.0347 - categorical_accuracy: 0.8663 - val_loss: 0.0118 - val_categorical_accuracy: 0.9553
# Epoch 2/10
# 14310/14310 [==============================] - 38s 3ms/step - loss: 0.0059 - categorical_accuracy: 0.9795 - val_loss: 0.0072 - val_categorical_accuracy: 0.9723
# Epoch 3/10
# 14310/14310 [==============================] - 64s 4ms/step - loss: 0.0032 - categorical_accuracy: 0.9892 - val_loss: 0.0067 - val_categorical_accuracy: 0.9730
# Epoch 4/10
# 14310/14310 [==============================] - 81s 6ms/step - loss: 0.0017 - categorical_accuracy: 0.9948 - val_loss: 0.0057 - val_categorical_accuracy: 0.9767
# Epoch 5/10
# 14310/14310 [==============================] - 80s 6ms/step - loss: 0.0012 - categorical_accuracy: 0.9965 - val_loss: 0.0068 - val_categorical_accuracy: 0.9761
# Epoch 6/10
# 14310/14310 [==============================] - 52s 4ms/step - loss: 0.0011 - categorical_accuracy: 0.9960 - val_loss: 0.0060 - val_categorical_accuracy: 0.9799
# Epoch 7/10
# 14310/14310 [==============================] - 80s 6ms/step - loss: 9.9998e-04 - categorical_accuracy: 0.9969 - val_loss: 0.0050 - val_categorical_accuracy: 0.9830
# Epoch 8/10
# 14310/14310 [==============================] - 92s 6ms/step - loss: 6.6067e-04 - categorical_accuracy: 0.9979 - val_loss: 0.0058 - val_categorical_accuracy: 0.9799
# Epoch 9/10
# 14310/14310 [==============================] - 84s 6ms/step - loss: 4.6668e-04 - categorical_accuracy: 0.9985 - val_loss: 0.0053 - val_categorical_accuracy: 0.9824
# Epoch 10/10
# 14310/14310 [==============================] - 81s 6ms/step - loss: 4.8721e-04 - categorical_accuracy: 0.9986 - val_loss: 0.0068 - val_categorical_accuracy: 0.9780
# Train on 14310 samples, validate on 1590 samples
# Epoch 1/10
# 14310/14310 [==============================] - 137s 10ms/step - loss: 0.0517 - categorical_accuracy: 0.7964 - val_loss: 0.0246 - val_categorical_accuracy: 0.9075
# Epoch 2/10
# 14310/14310 [==============================] - 127s 9ms/step - loss: 0.0168 - categorical_accuracy: 0.9410 - val_loss: 0.0151 - val_categorical_accuracy: 0.9415
# Epoch 3/10
# 14310/14310 [==============================] - 128s 9ms/step - loss: 0.0110 - categorical_accuracy: 0.9614 - val_loss: 0.0118 - val_categorical_accuracy: 0.9541
# Epoch 4/10
# 14310/14310 [==============================] - 127s 9ms/step - loss: 0.0081 - categorical_accuracy: 0.9714 - val_loss: 0.0097 - val_categorical_accuracy: 0.9623
# Epoch 5/10
# 14310/14310 [==============================] - 124s 9ms/step - loss: 0.0075 - categorical_accuracy: 0.9740 - val_loss: 0.0106 - val_categorical_accuracy: 0.9629
# Epoch 6/10
# 14310/14310 [==============================] - 125s 9ms/step - loss: 0.0060 - categorical_accuracy: 0.9802 - val_loss: 0.0084 - val_categorical_accuracy: 0.9717
# Epoch 7/10
# 14310/14310 [==============================] - 130s 9ms/step - loss: 0.0049 - categorical_accuracy: 0.9841 - val_loss: 0.0067 - val_categorical_accuracy: 0.9767
# Epoch 8/10
# 14310/14310 [==============================] - 105s 7ms/step - loss: 0.0037 - categorical_accuracy: 0.9878 - val_loss: 0.0077 - val_categorical_accuracy: 0.9723
# Epoch 9/10
# 14310/14310 [==============================] - 65s 5ms/step - loss: 0.0035 - categorical_accuracy: 0.9884 - val_loss: 0.0063 - val_categorical_accuracy: 0.9767
# Epoch 10/10
# 14310/14310 [==============================] - 61s 4ms/step - loss: 0.0024 - categorical_accuracy: 0.9919 - val_loss: 0.0064 - val_categorical_accuracy: 0.9755
# 1767/1767 [==============================] - 2s 1ms/step
# 1767/1767 [==============================] - 3s 1ms/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 350, 300)          1759800
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 348, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 200)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 250)               50250
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 250)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 22)                5522
# =================================================================
# Total params: 1,995,772
# Trainable params: 235,972
# Non-trainable params: 1,759,800
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 350, 300)          1759800
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 350, 300)          0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 346, 128)          192128
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 86, 128)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 70)                55720
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 70)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 22)                1562
# =================================================================
# Total params: 2,009,210
# Trainable params: 249,410
# Non-trainable params: 1,759,800
# _________________________________________________________________
# Train on 14310 samples, validate on 1590 samples
# Epoch 1/10
# 14310/14310 [==============================] - 55s 4ms/step - loss: 0.0301 - categorical_accuracy: 0.8818 - val_loss: 0.0097 - val_categorical_accuracy: 0.9654
# Epoch 2/10
# 14310/14310 [==============================] - 51s 4ms/step - loss: 0.0061 - categorical_accuracy: 0.9781 - val_loss: 0.0074 - val_categorical_accuracy: 0.9692
# Epoch 3/10
# 14310/14310 [==============================] - 51s 4ms/step - loss: 0.0031 - categorical_accuracy: 0.9885 - val_loss: 0.0054 - val_categorical_accuracy: 0.9805
# Epoch 4/10
# 14310/14310 [==============================] - 53s 4ms/step - loss: 0.0016 - categorical_accuracy: 0.9954 - val_loss: 0.0056 - val_categorical_accuracy: 0.9761
# Epoch 5/10
# 14310/14310 [==============================] - 51s 4ms/step - loss: 0.0010 - categorical_accuracy: 0.9969 - val_loss: 0.0057 - val_categorical_accuracy: 0.9786
# Epoch 6/10
# 14310/14310 [==============================] - 47s 3ms/step - loss: 9.4347e-04 - categorical_accuracy: 0.9969 - val_loss: 0.0056 - val_categorical_accuracy: 0.9824
# Epoch 7/10
# 14310/14310 [==============================] - 49s 3ms/step - loss: 8.7102e-04 - categorical_accuracy: 0.9974 - val_loss: 0.0051 - val_categorical_accuracy: 0.9836
# Epoch 8/10
# 14310/14310 [==============================] - 50s 4ms/step - loss: 7.7628e-04 - categorical_accuracy: 0.9976 - val_loss: 0.0062 - val_categorical_accuracy: 0.9811
# Epoch 9/10
# 14310/14310 [==============================] - 50s 3ms/step - loss: 7.1983e-04 - categorical_accuracy: 0.9973 - val_loss: 0.0055 - val_categorical_accuracy: 0.9818
# Epoch 10/10
# 14310/14310 [==============================] - 50s 3ms/step - loss: 6.0989e-04 - categorical_accuracy: 0.9982 - val_loss: 0.0075 - val_categorical_accuracy: 0.9767
# Train on 14310 samples, validate on 1590 samples
# Epoch 1/10
# 14310/14310 [==============================] - 89s 6ms/step - loss: 0.0537 - categorical_accuracy: 0.7936 - val_loss: 0.0237 - val_categorical_accuracy: 0.9088
# Epoch 2/10
# 14310/14310 [==============================] - 82s 6ms/step - loss: 0.0197 - categorical_accuracy: 0.9275 - val_loss: 0.0168 - val_categorical_accuracy: 0.9358
# Epoch 3/10
# 14310/14310 [==============================] - 81s 6ms/step - loss: 0.0132 - categorical_accuracy: 0.9532 - val_loss: 0.0130 - val_categorical_accuracy: 0.9522
# Epoch 4/10
# 14310/14310 [==============================] - 81s 6ms/step - loss: 0.0096 - categorical_accuracy: 0.9666 - val_loss: 0.0105 - val_categorical_accuracy: 0.9597
# Epoch 5/10
# 14310/14310 [==============================] - 81s 6ms/step - loss: 0.0073 - categorical_accuracy: 0.9746 - val_loss: 0.0107 - val_categorical_accuracy: 0.9616
# Epoch 6/10
# 14310/14310 [==============================] - 81s 6ms/step - loss: 0.0067 - categorical_accuracy: 0.9764 - val_loss: 0.0134 - val_categorical_accuracy: 0.9535
# Epoch 7/10
# 14310/14310 [==============================] - 82s 6ms/step - loss: 0.0062 - categorical_accuracy: 0.9790 - val_loss: 0.0093 - val_categorical_accuracy: 0.9616
# Epoch 8/10
# 14310/14310 [==============================] - 81s 6ms/step - loss: 0.0050 - categorical_accuracy: 0.9832 - val_loss: 0.0094 - val_categorical_accuracy: 0.9610
# Epoch 9/10
# 14310/14310 [==============================] - 81s 6ms/step - loss: 0.0042 - categorical_accuracy: 0.9858 - val_loss: 0.0086 - val_categorical_accuracy: 0.9648
# Epoch 10/10
# 14310/14310 [==============================] - 78s 5ms/step - loss: 0.0030 - categorical_accuracy: 0.9898 - val_loss: 0.0074 - val_categorical_accuracy: 0.9730
# 1767/1767 [==============================] - 3s 1ms/step
# 1767/1767 [==============================] - 4s 2ms/step
# ['Flipkart/250BestLayerCNNswithLSTM.sav']

# %%
print("CNNs: "+ str(max(Scores)))
print("CNNs+LSTM: "+ str(max(Scores2)))
# Out:
# CNNs: 0.9830220806848281
# CNNs+LSTM: 0.976796842660348

# %%
test = pad_sequences(sequences_test,maxlen = bestLength)
yConfidence = bestModel.predict(test)
yPred = [ np.argmax(ele) for ele in yConfidence ]

# %%
fig,ax  = plt.subplots()
ax.plot(Lengths,Scores,label="CNNs")
ax.plot(Lengths,Scores2,label="CNNs+LSTM")

ax.set_xlabel("Length of pad sequence")
ax.set_ylabel("Accuracy")
ax.legend()
ax.grid()
fig.savefig("Flipkart/CNNsbestsequenceLength.png")

# %%
totalConfidenceSize = yConfidence.shape[0]*yConfidence.shape[1]
Confidence1DArr = yConfidence.reshape(totalConfidenceSize,1)
Max = ceil(max(Confidence1DArr)[0])
Min = floor(min(Confidence1DArr)[0])
NormalisedConfid = [round((max(ele)-Min)/(Max-Min),2) for ele in yConfidence]
productID = [ df[df.index==ele]['pid'].values[0] for ele in y_test_info['index'] ]
ProductDescription =[ df[df.index==ele]['description'].values[0] for ele in y_test_info['index'] ]
CNNResult = pd.DataFrame({'id':productID,'description':ProductDescription,
                         'trueClass': y_test,'trueClassNaem':target[y_test] ,
                         'predictClass':yPred,'predictClassName':target[yPred],
                         'Confidence':NormalisedConfid})
CNNResult.to_csv("Flipkart/CNNResults.csv",index=False,compression=None)

# %%
def draw_confidenceReport(data):
    num = [ ele*0.01 for ele in range(20,81,2)]
    totalitems = []
    correct = []
    incorrect = []
    for ele in num:
        Threshold = data[data['Confidence']>ele]
        correct.append(len(Threshold[Threshold['trueClass']==Threshold['predictClass']].index))
        incorrect.append(len(Threshold[Threshold['trueClass']!=Threshold['predictClass']].index))
        totalitems.append(len(Threshold.index))
    
    ClassfiedProportion = [ ele/len(data.index) for ele in totalitems]
    
    Acc =[]
    for ele in zip(correct,totalitems):
        if (ele[1]==0):
            Acc.append(0)
        else:
            Acc.append(ele[0]/ele[1])

    fig,ax  = plt.subplots()
    
    color = 'tab:blue'
    ax.scatter(num,ClassfiedProportion,label="Proportion classified",color=color)
    ax.set_xlabel("Confidence Score")
    ax.set_ylabel("Proportion classified", color=color)
    ax.xaxis.set_ticks(np.arange(0,1.1,0.1))
    ax.yaxis.set_ticks(np.arange(0,1.1,0.1))
    ax.tick_params(axis='y', labelcolor=color)

    color = 'tab:red'

    ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis

    ax2.scatter(num,Acc,label="Accuracy", color=color)
    ax2.set_ylabel("Accuracy", color=color)
    ax2.yaxis.set_ticks(np.arange(0,1.1,0.1))
    ax2.tick_params(axis='y', labelcolor=color)

    ax.grid()
    fig.savefig("Flipkart/ConfidenceScoreReportCNN.png")

# %%
print(classification_report(y_test, yPred,target_names=target))
with open('Flipkart/CNNReport.txt', 'w') as file:
    file.write(classification_report(y_test, yPred,target_names=target))
# Out:
#                                     precision    recall  f1-score   support
#
#                        Automotive        0.95      1.00      0.98        98
#                         Baby Care        0.89      0.94      0.91        34
#             Bags, Wallets & Belts        0.95      1.00      0.97        19
#          Beauty and Personal Care        0.98      0.98      0.98        64
#             Cameras & Accessories        1.00      1.00      1.00         7
#                          Clothing        1.00      1.00      1.00       627
#                         Computers        0.95      1.00      0.97        57
#                          Footwear        1.00      0.98      0.99       124
#                         Furniture        1.00      1.00      1.00         4
#                            Gaming        1.00      0.62      0.77         8
# Health & Personal Care Appliances        1.00      1.00      1.00         2
#        Home Decor & Festive Needs        0.98      0.95      0.96        86
#                   Home Furnishing        0.99      0.99      0.99        77
#                  Home Improvement        0.83      0.83      0.83         6
#                         Jewellery        1.00      1.00      1.00       234
#                  Kitchen & Dining        1.00      0.98      0.99        55
#             Mobiles & Accessories        0.98      0.97      0.98       113
#                 Pens & Stationery        0.76      1.00      0.86        25
#                  Sports & Fitness        1.00      1.00      1.00         9
#                  Tools & Hardware        0.98      0.95      0.96        42
#            Toys & School Supplies        1.00      0.68      0.81        22
#                           Watches        1.00      1.00      1.00        54
#
#                          micro avg       0.98      0.98      0.98      1767
#                          macro avg       0.97      0.95      0.95      1767
#                       weighted avg       0.98      0.98      0.98      1767

# %%
draw_confidenceReport(CNNResult)

# %%
cm = confusion_matrix(y_test, yPred)

# %%
fig, ax = plt.subplots(figsize=(8,8))
im =ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
classes = target[unique_labels(y_test, yPred)]
# We want to show all ticks...
ax.set(xticks=np.arange(cm.shape[1]),yticks=np.arange(cm.shape[0]),
       # ... and label them with the respective list entries
        xticklabels=classes, yticklabels=classes,ylabel='True label',xlabel='Predicted label')
# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
fmt = 'd'
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),ha="center", va="center", color="white" if cm[i, j] > thresh else "black")
fig.tight_layout()
fig.savefig("Flipkart/CNNConfusionMatrix.png")
