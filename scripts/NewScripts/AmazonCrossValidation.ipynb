# %%
import pandas as pd 
import numpy as np
import os 

from sklearn.model_selection import cross_validate,train_test_split
from sklearn.preprocessing import LabelEncoder,scale
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.naive_bayes import ComplementNB,MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 11})

import re
import nltk
from nltk.corpus import stopwords


from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Activation, Conv1D, Dense, Embedding, Flatten, Input, Dropout, GlobalMaxPooling1D
from keras.metrics import categorical_accuracy
from keras.callbacks import  EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;-]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))
Number_RE = re.compile('[*^0-9]')
Bad_underline = re.compile('[*_*]')
RemoveTag = re.compile('&lt;|br&gt;|b&gt;|ul&gt;|li&gt;')

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = RemoveTag.sub('',text)
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = Number_RE.sub(' ', text) # replace Number symbols by space in text
    text = Bad_underline.sub(' ', text) # replace Underline symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text
RemoveLastSpace = re.compile(' $')

def clean_text_category(text):
    text = RemoveLastSpace.sub('',text)
    return text

# %%
def classNumberThreshold(arr):
    dropCategory = []

    for key,value in arr.items():
        if(value<=30):
            dropCategory.append(key)
    return dropCategory

# %%
df = pd.read_csv('../../example/amazon_co-ecommerce_sample.csv')

# %%
df = df[pd.notnull(df['amazon_category_and_sub_category'])]
df = df[pd.notnull(df['description'])]
df = df[pd.notnull(df['uniq_id'])]
category = []
subcategory = []
sub2category = []
for ele in df['amazon_category_and_sub_category'].apply(lambda x: str(x).split('>')):
    category.append(ele[0])
    if(len(ele)>2):
        subcategory.append(ele[1])
        sub2category.append(ele[2])
    elif(len(ele)>1):
        subcategory.append(ele[1])
        sub2category.append(np.NaN)
    else:
        subcategory.append(np.NaN)
        sub2category.append(np.NaN)

data= {'uniq_id':df['uniq_id'], 'product_name':df['product_name'],'category_main':category,'category_sub1':subcategory,'description':df['description']}
df = pd.DataFrame(data)
df['description'] = df['description'].apply(clean_text)
df.category_main = df['category_main'].apply(clean_text_category)
df.category_sub1 = df['category_sub1'].apply(clean_text_category)

df = df[pd.notnull(df['category_main'])]
df = df[pd.notnull(df['category_sub1'])]

# %%
dropCategoryCode  = classNumberThreshold(df.category_main.value_counts())
dropSubCategoryCode  = classNumberThreshold(df.category_sub1.value_counts())

for i in dropCategoryCode:
    df = df[df.category_main!=i]
    
for i in dropSubCategoryCode:
    df = df[df.category_sub1!=i]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8189 entries, 0 to 9998
# Data columns (total 5 columns):
# uniq_id          8189 non-null object
# product_name     8189 non-null object
# category_main    8189 non-null object
# category_sub1    8189 non-null object
# description      8189 non-null object
# dtypes: object(5)
# memory usage: 383.9+ KB

# %%
le = LabelEncoder()
le.fit(df.category_main)
target = le.classes_
labels = le.transform(df['category_main'])

le.fit(df.category_sub1.apply(str))
subtarget = le.classes_
sublabels = le.transform(df['category_sub1'])

# %%
tfidfconverter = TfidfVectorizer(min_df=5, max_df=0.7)
X = tfidfconverter.fit_transform(df.description)

# %%
K = [2, 3, 4, 5, 10]
testSize = [ 1/ele for ele in K ]
CNBCresults = []
MNBCresults = []
for ele in K:
    MNBC = MultinomialNB()
    CNBC = ComplementNB()
    mnbcresult = cross_validate(MNBC, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    cnbcresult = cross_validate(CNBC, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    CNBCresults.append(cnbcresult)
    MNBCresults.append(mnbcresult)
# Out:
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/justin/mscproject/app/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
SVCresults = []
for ele in K:
    linearsvc = LinearSVC(random_state=42, class_weight="balanced")
    result = cross_validate(linearsvc, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    SVCresults.append(result)

# %%
def result_report(results):
    mean_result_report = []
    for ele in results:
        mean_result = {}
        for key,value in ele.items():
            mean_result[key] = round(np.mean(value),2)
        mean_result_report.append(mean_result)
    return mean_result_report

MNBCReport = result_report(MNBCresults)
CNBCReport = result_report(CNBCresults)
SVCReport = result_report(SVCresults)

# %%
MNBCReport,CNBCReport,SVCReport
# Out:
# ([{'fit_time': 0.01,
#    'score_time': 0.06,
#    'test_f1_micro': 0.58,
#    'train_f1_micro': 0.86,
#    'test_f1_macro': 0.44,
#    'train_f1_macro': 0.74,
#    'test_f1_weighted': 0.56,
#    'train_f1_weighted': 0.86,
#    'test_accuracy': 0.58,
#    'train_accuracy': 0.86},
#   {'fit_time': 0.01,
#    'score_time': 0.01,
#    'test_f1_micro': 0.67,
#    'train_f1_micro': 0.85,
#    'test_f1_macro': 0.56,
#    'train_f1_macro': 0.72,
#    'test_f1_weighted': 0.65,
#    'train_f1_weighted': 0.85,
#    'test_accuracy': 0.67,
#    'train_accuracy': 0.85},
#   {'fit_time': 0.01,
#    'score_time': 0.01,
#    'test_f1_micro': 0.7,
#    'train_f1_micro': 0.85,
#    'test_f1_macro': 0.59,
#    'train_f1_macro': 0.72,
#    'test_f1_weighted': 0.69,
#    'train_f1_weighted': 0.84,
#    'test_accuracy': 0.7,
#    'train_accuracy': 0.85},
#   {'fit_time': 0.01,
#    'score_time': 0.01,
#    'test_f1_micro': 0.72,
#    'train_f1_micro': 0.85,
#    'test_f1_macro': 0.61,
#    'train_f1_macro': 0.72,
#    'test_f1_weighted': 0.7,
#    'train_f1_weighted': 0.84,
#    'test_accuracy': 0.72,
#    'train_accuracy': 0.85},
#   {'fit_time': 0.01,
#    'score_time': 0.0,
#    'test_f1_micro': 0.74,
#    'train_f1_micro': 0.85,
#    'test_f1_macro': 0.63,
#    'train_f1_macro': 0.72,
#    'test_f1_weighted': 0.73,
#    'train_f1_weighted': 0.84,
#    'test_accuracy': 0.74,
#    'train_accuracy': 0.85}],
#  [{'fit_time': 0.01,
#    'score_time': 0.01,
#    'test_f1_micro': 0.64,
#    'train_f1_micro': 0.9,
#    'test_f1_macro': 0.6,
#    'train_f1_macro': 0.91,
#    'test_f1_weighted': 0.63,
#    'train_f1_weighted': 0.9,
#    'test_accuracy': 0.64,
#    'train_accuracy': 0.9},
#   {'fit_time': 0.01,
#    'score_time': 0.01,
#    'test_f1_micro': 0.72,
#    'train_f1_micro': 0.89,
#    'test_f1_macro': 0.7,
#    'train_f1_macro': 0.89,
#    'test_f1_weighted': 0.71,
#    'train_f1_weighted': 0.88,
#    'test_accuracy': 0.72,
#    'train_accuracy': 0.89},
#   {'fit_time': 0.01,
#    'score_time': 0.01,
#    'test_f1_micro': 0.74,
#    'train_f1_micro': 0.88,
#    'test_f1_macro': 0.72,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.73,
#    'train_f1_weighted': 0.88,
#    'test_accuracy': 0.74,
#    'train_accuracy': 0.88},
#   {'fit_time': 0.01,
#    'score_time': 0.01,
#    'test_f1_micro': 0.75,
#    'train_f1_micro': 0.88,
#    'test_f1_macro': 0.73,
#    'train_f1_macro': 0.88,
#    'test_f1_weighted': 0.74,
#    'train_f1_weighted': 0.87,
#    'test_accuracy': 0.75,
#    'train_accuracy': 0.88},
#   {'fit_time': 0.01,
#    'score_time': 0.0,
#    'test_f1_micro': 0.77,
#    'train_f1_micro': 0.87,
#    'test_f1_macro': 0.74,
#    'train_f1_macro': 0.87,
#    'test_f1_weighted': 0.76,
#    'train_f1_weighted': 0.87,
#    'test_accuracy': 0.77,
#    'train_accuracy': 0.87}],
#  [{'fit_time': 0.21,
#    'score_time': 0.01,
#    'test_f1_micro': 0.65,
#    'train_f1_micro': 0.98,
#    'test_f1_macro': 0.63,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.64,
#    'train_f1_weighted': 0.98,
#    'test_accuracy': 0.65,
#    'train_accuracy': 0.98},
#   {'fit_time': 0.27,
#    'score_time': 0.01,
#    'test_f1_micro': 0.72,
#    'train_f1_micro': 0.98,
#    'test_f1_macro': 0.72,
#    'train_f1_macro': 0.98,
#    'test_f1_weighted': 0.72,
#    'train_f1_weighted': 0.98,
#    'test_accuracy': 0.72,
#    'train_accuracy': 0.98},
#   {'fit_time': 0.31,
#    'score_time': 0.01,
#    'test_f1_micro': 0.75,
#    'train_f1_micro': 0.98,
#    'test_f1_macro': 0.75,
#    'train_f1_macro': 0.98,
#    'test_f1_weighted': 0.74,
#    'train_f1_weighted': 0.98,
#    'test_accuracy': 0.75,
#    'train_accuracy': 0.98},
#   {'fit_time': 0.33,
#    'score_time': 0.01,
#    'test_f1_micro': 0.76,
#    'train_f1_micro': 0.97,
#    'test_f1_macro': 0.77,
#    'train_f1_macro': 0.98,
#    'test_f1_weighted': 0.76,
#    'train_f1_weighted': 0.97,
#    'test_accuracy': 0.76,
#    'train_accuracy': 0.97},
#   {'fit_time': 0.38,
#    'score_time': 0.0,
#    'test_f1_micro': 0.78,
#    'train_f1_micro': 0.97,
#    'test_f1_macro': 0.79,
#    'train_f1_macro': 0.98,
#    'test_f1_weighted': 0.78,
#    'train_f1_weighted': 0.97,
#    'test_accuracy': 0.78,
#    'train_accuracy': 0.97}])

# %%
embedding_dim = 300 # We use 100 dimensional glove vectors
glove_dir = '../../glove.6B' # This is the folder with the dataset
embeddings_index = {} # We create a dictionary of word -> embedding
with open(os.path.join(glove_dir, 'glove.6B.300d.txt')) as f:
    for line in f:
        values = line.split()
        word = values[0] # The first value is the word, the rest are the values of the embedding
        embedding = np.asarray(values[1:], dtype='float32') # Load embedding
        embeddings_index[word] = embedding # Add embedding to our embedding dictionary
    print('Found {:,} word vectors in GloVe.'.format(len(embeddings_index)))
# Out:
# Found 400,000 word vectors in GloVe.

# %%
def tokenizer_and_pad_sequence (Xtrain,Xtest,vocab_size,embeddings_index):
    tokenizer = Tokenizer(num_words=vocab_size) # Setup tokenizer
    tokenizer.fit_on_texts(Xtrain)
    
    sequences = tokenizer.texts_to_sequences(Xtrain)
    sequences_test = tokenizer.texts_to_sequences(Xtest)
    
    trainlengths = [len(ele) for ele in sequences]
    testlengths = [len(ele) for ele in sequences_test]
    max_length = min(max(trainlengths),max(testlengths))
    
    train = pad_sequences(sequences,maxlen= max_length)
    test = pad_sequences(sequences_test,maxlen = max_length)
    
    word_index = tokenizer.word_index
    embedding_dim = 300
    nb_words = min(vocab_size, len(word_index)) # How many words are there actually
    embedding_matrix = np.zeros((nb_words, embedding_dim))
    # The vectors need to be in the same position as their index. 
    # Meaning a word with token 1 needs to be in the second row (rows start with zero) and so on
    # Loop over all words in the word index
    for word, i in word_index.items():
        # If we are above the amount of words we want to use we do nothing
        if i >= vocab_size: 
            continue
        # Get the embedding vector for the word
        embedding_vector = embeddings_index.get(word)
        # If there is an embedding vector, put it in the embedding matrix
        if embedding_vector is not None: 
            embedding_matrix[i] = embedding_vector
    return train, test, max_length, embedding_matrix

def model_settings(length,vocabSize,embeddingMatrix,outputnum):
        embedding_dim = 300
        model = Sequential()
        model.add(Embedding(vocab_size, embedding_dim, input_length=length, weights = [embedding_matrix], 
                                trainable = False))
        model.add(Conv1D(200,3,padding='valid',activation='relu',strides=1))        
        # we use max pooling:
        model.add(GlobalMaxPooling1D())
        # We add a vanilla hidden layer:
        model.add(Dense(250))
        model.add(Dropout(0.2))
        model.add(Dense(outputnum, activation='softmax'))
        model.summary()
        return model

def fit_evaluate(model,Xtrain, ytrain,Xtest,ytest):
    EPOCHS = 10
    BATCH_SIZE = 100
    #set early stopping criteria
    pat = 5 #this is the number of epochs with no improvment after which the training will stop
    early_stopping = EarlyStopping(monitor='val_loss', patience=pat, verbose=1)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[categorical_accuracy])
    result = model.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=BATCH_SIZE, 
                        callbacks=[early_stopping], 
              verbose=1, validation_split=0.1)
    score = model.evaluate(Xtest, ytest, batch_size=BATCH_SIZE)
    return result,score

# %%
vocab_size = len(tfidfconverter.get_feature_names())
KFoldTrainResults = []
KFoldTestResults  = []
for i in testSize:
    print("------ "+str(i)+" testing size ------\n")
    Xtrain, Xtest, ytrain , ytest = train_test_split(df['description'].apply(str), labels, test_size= i, random_state = 42)
    categoricalLabel = to_categorical(ytrain)
    categoricalTestLabel = to_categorical(ytest)
    train, test, max_length, embedding_matrix =  tokenizer_and_pad_sequence(Xtrain,Xtest,vocab_size,embeddings_index)
    model = model_settings(max_length,vocab_size,embedding_matrix,len(np.unique(ytrain)))
    result,score = fit_evaluate(model,train,categoricalLabel,test,categoricalTestLabel)
    KFoldTrainResults.append(result)
    KFoldTestResults.append(score)
# Out:
# ------ 0.5 testing size ------
# WARNING: Logging before flag parsing goes to stderr.
# W0830 09:54:28.779671 140357028288320 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0830 09:54:29.045567 140357028288320 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0830 09:54:29.167631 140357028288320 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0830 09:54:29.202656 140357028288320 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0830 09:54:29.203840 140357028288320 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0830 09:54:30.659194 140357028288320 deprecation.py:506] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0830 09:54:30.688462 140357028288320 deprecation_wrapper.py:119] From /home/justin/mscproject/app/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0830 09:54:30.710977 140357028288320 deprecation.py:323] From /home/justin/mscproject/app/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 522, 300)          2023800
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 520, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 14)                3514
# =================================================================
# Total params: 2,257,764
# Trainable params: 233,964
# Non-trainable params: 2,023,800
# _________________________________________________________________
# Train on 3684 samples, validate on 410 samples
# Epoch 1/10
# 3684/3684 [==============================] - 9s 3ms/step - loss: 0.1865 - categorical_accuracy: 0.4264 - val_loss: 0.1275 - val_categorical_accuracy: 0.6537
# Epoch 2/10
# 3684/3684 [==============================] - 7s 2ms/step - loss: 0.0937 - categorical_accuracy: 0.7638 - val_loss: 0.1005 - val_categorical_accuracy: 0.7024
# Epoch 3/10
# 3684/3684 [==============================] - 7s 2ms/step - loss: 0.0575 - categorical_accuracy: 0.8711 - val_loss: 0.0873 - val_categorical_accuracy: 0.7488
# Epoch 4/10
# 3684/3684 [==============================] - 7s 2ms/step - loss: 0.0341 - categorical_accuracy: 0.9281 - val_loss: 0.0872 - val_categorical_accuracy: 0.7756
# Epoch 5/10
# 3684/3684 [==============================] - 7s 2ms/step - loss: 0.0218 - categorical_accuracy: 0.9604 - val_loss: 0.0865 - val_categorical_accuracy: 0.7415
# Epoch 6/10
# 3684/3684 [==============================] - 7s 2ms/step - loss: 0.0137 - categorical_accuracy: 0.9786 - val_loss: 0.0924 - val_categorical_accuracy: 0.7683
# Epoch 7/10
# 3684/3684 [==============================] - 7s 2ms/step - loss: 0.0100 - categorical_accuracy: 0.9875 - val_loss: 0.0942 - val_categorical_accuracy: 0.7561
# Epoch 8/10
# 3684/3684 [==============================] - 7s 2ms/step - loss: 0.0093 - categorical_accuracy: 0.9840 - val_loss: 0.0975 - val_categorical_accuracy: 0.7634
# Epoch 9/10
# 3684/3684 [==============================] - 7s 2ms/step - loss: 0.0077 - categorical_accuracy: 0.9889 - val_loss: 0.1092 - val_categorical_accuracy: 0.7366
# Epoch 10/10
# 3684/3684 [==============================] - 7s 2ms/step - loss: 0.0074 - categorical_accuracy: 0.9881 - val_loss: 0.1008 - val_categorical_accuracy: 0.7659
# Epoch 00010: early stopping
# 4095/4095 [==============================] - 3s 805us/step
# ------ 0.3333333333333333 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 520, 300)          2023800
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 518, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 200)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 14)                3514
# =================================================================
# Total params: 2,257,764
# Trainable params: 233,964
# Non-trainable params: 2,023,800
# _________________________________________________________________
# Train on 4913 samples, validate on 546 samples
# Epoch 1/10
# 4913/4913 [==============================] - 10s 2ms/step - loss: 0.1695 - categorical_accuracy: 0.4944 - val_loss: 0.1073 - val_categorical_accuracy: 0.7070
# Epoch 2/10
# 4913/4913 [==============================] - 10s 2ms/step - loss: 0.0822 - categorical_accuracy: 0.7855 - val_loss: 0.0949 - val_categorical_accuracy: 0.7344
# Epoch 3/10
# 4913/4913 [==============================] - 10s 2ms/step - loss: 0.0529 - categorical_accuracy: 0.8685 - val_loss: 0.0958 - val_categorical_accuracy: 0.7418
# Epoch 4/10
# 4913/4913 [==============================] - 10s 2ms/step - loss: 0.0346 - categorical_accuracy: 0.9229 - val_loss: 0.0845 - val_categorical_accuracy: 0.7656
# Epoch 5/10
# 4913/4913 [==============================] - 10s 2ms/step - loss: 0.0227 - categorical_accuracy: 0.9550 - val_loss: 0.0917 - val_categorical_accuracy: 0.7564
# Epoch 6/10
# 4913/4913 [==============================] - 10s 2ms/step - loss: 0.0159 - categorical_accuracy: 0.9739 - val_loss: 0.0913 - val_categorical_accuracy: 0.7509
# Epoch 7/10
# 4913/4913 [==============================] - 10s 2ms/step - loss: 0.0126 - categorical_accuracy: 0.9801 - val_loss: 0.0997 - val_categorical_accuracy: 0.7656
# Epoch 8/10
# 4913/4913 [==============================] - 10s 2ms/step - loss: 0.0111 - categorical_accuracy: 0.9815 - val_loss: 0.1050 - val_categorical_accuracy: 0.7637
# Epoch 9/10
# 4913/4913 [==============================] - 10s 2ms/step - loss: 0.0103 - categorical_accuracy: 0.9843 - val_loss: 0.1045 - val_categorical_accuracy: 0.7436
# Epoch 00009: early stopping
# 2730/2730 [==============================] - 2s 813us/step
# ------ 0.25 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 521, 300)          2023800
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 519, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 200)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 14)                3514
# =================================================================
# Total params: 2,257,764
# Trainable params: 233,964
# Non-trainable params: 2,023,800
# _________________________________________________________________
# Train on 5526 samples, validate on 615 samples
# Epoch 1/10
# 5526/5526 [==============================] - 12s 2ms/step - loss: 0.1629 - categorical_accuracy: 0.5226 - val_loss: 0.1039 - val_categorical_accuracy: 0.7106
# Epoch 2/10
# 5526/5526 [==============================] - 11s 2ms/step - loss: 0.0777 - categorical_accuracy: 0.7999 - val_loss: 0.0897 - val_categorical_accuracy: 0.7463
# Epoch 3/10
# 5526/5526 [==============================] - 11s 2ms/step - loss: 0.0510 - categorical_accuracy: 0.8742 - val_loss: 0.0839 - val_categorical_accuracy: 0.7528
# Epoch 4/10
# 5526/5526 [==============================] - 11s 2ms/step - loss: 0.0331 - categorical_accuracy: 0.9245 - val_loss: 0.0895 - val_categorical_accuracy: 0.7740
# Epoch 5/10
# 5526/5526 [==============================] - 11s 2ms/step - loss: 0.0219 - categorical_accuracy: 0.9567 - val_loss: 0.0939 - val_categorical_accuracy: 0.7610
# Epoch 6/10
# 5526/5526 [==============================] - 11s 2ms/step - loss: 0.0145 - categorical_accuracy: 0.9759 - val_loss: 0.0938 - val_categorical_accuracy: 0.7707
# Epoch 7/10
# 5526/5526 [==============================] - 11s 2ms/step - loss: 0.0124 - categorical_accuracy: 0.9792 - val_loss: 0.1053 - val_categorical_accuracy: 0.7610
# Epoch 8/10
# 5526/5526 [==============================] - 11s 2ms/step - loss: 0.0115 - categorical_accuracy: 0.9814 - val_loss: 0.1121 - val_categorical_accuracy: 0.7561
# Epoch 00008: early stopping
# 2048/2048 [==============================] - 2s 762us/step
# ------ 0.2 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 518, 300)          2023800
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 516, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 200)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 14)                3514
# =================================================================
# Total params: 2,257,764
# Trainable params: 233,964
# Non-trainable params: 2,023,800
# _________________________________________________________________
# Train on 5895 samples, validate on 656 samples
# Epoch 1/10
# 5895/5895 [==============================] - 12s 2ms/step - loss: 0.1596 - categorical_accuracy: 0.5389 - val_loss: 0.1033 - val_categorical_accuracy: 0.7165
# Epoch 2/10
# 5895/5895 [==============================] - 11s 2ms/step - loss: 0.0772 - categorical_accuracy: 0.8019 - val_loss: 0.0835 - val_categorical_accuracy: 0.7607
# Epoch 3/10
# 5895/5895 [==============================] - 11s 2ms/step - loss: 0.0479 - categorical_accuracy: 0.8884 - val_loss: 0.0814 - val_categorical_accuracy: 0.7851
# Epoch 4/10
# 5895/5895 [==============================] - 11s 2ms/step - loss: 0.0301 - categorical_accuracy: 0.9347 - val_loss: 0.0830 - val_categorical_accuracy: 0.7805
# Epoch 5/10
# 5895/5895 [==============================] - 11s 2ms/step - loss: 0.0197 - categorical_accuracy: 0.9657 - val_loss: 0.0869 - val_categorical_accuracy: 0.7835
# Epoch 6/10
# 5895/5895 [==============================] - 11s 2ms/step - loss: 0.0145 - categorical_accuracy: 0.9776 - val_loss: 0.0848 - val_categorical_accuracy: 0.7927
# Epoch 7/10
# 5895/5895 [==============================] - 11s 2ms/step - loss: 0.0130 - categorical_accuracy: 0.9790 - val_loss: 0.0964 - val_categorical_accuracy: 0.8034
# Epoch 8/10
# 5895/5895 [==============================] - 11s 2ms/step - loss: 0.0118 - categorical_accuracy: 0.9810 - val_loss: 0.0906 - val_categorical_accuracy: 0.7912
# Epoch 00008: early stopping
# 1638/1638 [==============================] - 1s 747us/step
# ------ 0.1 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 452, 300)          2023800
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 450, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 200)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 14)                3514
# =================================================================
# Total params: 2,257,764
# Trainable params: 233,964
# Non-trainable params: 2,023,800
# _________________________________________________________________
# Train on 6633 samples, validate on 737 samples
# Epoch 1/10
# 6633/6633 [==============================] - 12s 2ms/step - loss: 0.1553 - categorical_accuracy: 0.5482 - val_loss: 0.1002 - val_categorical_accuracy: 0.7191
# Epoch 2/10
# 6633/6633 [==============================] - 11s 2ms/step - loss: 0.0761 - categorical_accuracy: 0.8051 - val_loss: 0.0906 - val_categorical_accuracy: 0.7436
# Epoch 3/10
# 6633/6633 [==============================] - 11s 2ms/step - loss: 0.0492 - categorical_accuracy: 0.8817 - val_loss: 0.0846 - val_categorical_accuracy: 0.7693
# Epoch 4/10
# 6633/6633 [==============================] - 11s 2ms/step - loss: 0.0319 - categorical_accuracy: 0.9284 - val_loss: 0.0857 - val_categorical_accuracy: 0.7802
# Epoch 5/10
# 6633/6633 [==============================] - 11s 2ms/step - loss: 0.0210 - categorical_accuracy: 0.9622 - val_loss: 0.0863 - val_categorical_accuracy: 0.7843
# Epoch 6/10
# 6633/6633 [==============================] - 11s 2ms/step - loss: 0.0160 - categorical_accuracy: 0.9729 - val_loss: 0.0890 - val_categorical_accuracy: 0.7843
# Epoch 7/10
# 6633/6633 [==============================] - 11s 2ms/step - loss: 0.0160 - categorical_accuracy: 0.9724 - val_loss: 0.0967 - val_categorical_accuracy: 0.7748
# Epoch 8/10
# 6633/6633 [==============================] - 11s 2ms/step - loss: 0.0119 - categorical_accuracy: 0.9796 - val_loss: 0.0950 - val_categorical_accuracy: 0.7883
# Epoch 00008: early stopping
# 819/819 [==============================] - 1s 655us/step

# %%
fig, (ax,ax2) = plt.subplots(2, 1,figsize=(5,10))
for ele in KFoldTrainResults:
    currentTestsize = testSize[KFoldTrainResults.index(ele)]
    ax.plot(ele.history['categorical_accuracy'],label= str(round(1-currentTestsize,2))+" testing size")

    ax.legend()
ax.set_title('Categorical Accuracy Accuracy')
ax.set_xlabel("Epoch")
ax.set_ylabel("Validation categoryical accuracy")

for ele in KFoldTrainResults:
    currentTestsize = testSize[KFoldTrainResults.index(ele)]
    ax2.plot(ele.history['val_categorical_accuracy'],label= str(round(1-currentTestsize,2))+" testing size")
    ax2.legend()
ax2.set_title('Validation categoryical accuracy')
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Validation categoryical accuracy")

fig.savefig("AmazonCNNsTrainCrossValidation.png", bbox_inches='tight')

# %%
fig, (ax1,ax3) = plt.subplots(2, 1,figsize=(5,10))
fig.subplots_adjust(hspace=0.5)
trainSize = [ (1-1/ele) for ele in K ]
ytrainTimeMNBC = [ ele['fit_time'] for ele in MNBCReport]
ytrainTimeCNBC = [ ele['fit_time'] for ele in CNBCReport]
ytrainTimeSVC = [ ele['fit_time'] for ele in SVCReport]
ytestTimeMNBC = [ ele['score_time'] for ele in MNBCReport]
ytestTimeCNBC = [ ele['score_time'] for ele in CNBCReport]
ytestTimeSVC = [ ele['score_time'] for ele in SVCReport]
yAccMNBC = [ ele['test_accuracy'] for ele in MNBCReport]
yAccCNBC = [ ele['test_accuracy'] for ele in CNBCReport]
yAccSVC = [ ele['test_accuracy'] for ele in SVCReport]
yAccCNNs = [ele[1] for ele in KFoldTestResults]
line1, = ax1.plot(trainSize, ytrainTimeMNBC, color="tab:red", label = "MNBC Training" )
line2, = ax1.plot(trainSize, ytrainTimeCNBC, color="tab:blue", label = "CNBC Training" )
line3, = ax1.plot(trainSize, ytrainTimeSVC, color="tab:orange", label = "SVC Training" )
line1.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break
line2.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break
line3.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break

ax1.set_title('Training and Testing Time')
ax1.set_xlabel("Size of training set")
ax1.set_ylabel("Training time (us)")
step1 = (max(ytrainTimeSVC) - min(ytrainTimeSVC))/len(ytrainTimeSVC)
ax1.yaxis.set_ticks(np.arange(0,max(ytrainTimeSVC),step1))
ax1.xaxis.set_ticks(np.arange(0,1,0.1))

# ax1.grid()
ax1.legend(loc=4)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(trainSize, ytestTimeMNBC, color="tab:red", label = "MNBC Testing" )
ax2.plot(trainSize, ytestTimeCNBC, color="tab:blue", label = "CNBC Testing" )
ax2.plot(trainSize, ytestTimeSVC, color="tab:orange", label = "SVC Testing" )
ax2.set_ylabel("Testing time (us)")
step2 = (max(ytestTimeSVC) - min(ytestTimeSVC))/len(ytestTimeSVC)
ax2.yaxis.set_ticks(np.arange(0,max(ytestTimeSVC),step2))
# ax2.grid()
ax2.legend(loc=1)
ax3.plot(trainSize, yAccMNBC, color="tab:red", label = "MNBC" )
ax3.plot(trainSize, yAccCNBC, color="tab:blue", label = "CNBC" )
ax3.plot(trainSize, yAccSVC, color="tab:orange", label = "SVC" )
ax3.plot(trainSize, yAccCNNs, color="tab:green", label = "CNNs" )

ax3.set_title('Accuracy')
ax3.set_xlabel("Size of training set")
ax3.set_ylabel("Accuracy")

ax3.grid()
ax3.legend()

fig.savefig("AmazonCrossValidation.png", bbox_inches='tight')
print(K[np.argmax(yAccMNBC)])
print(K[np.argmax(yAccCNBC)])
print(K[np.argmax(yAccSVC)])
print(K[np.argmax(yAccCNNs)])
# Out:
# 10
# 10
# 10
# 10
