# %%
import pandas as pd 
import numpy as np
import os 

from sklearn.model_selection import cross_validate,train_test_split
from sklearn.preprocessing import LabelEncoder,scale
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.naive_bayes import ComplementNB
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 11})

import re
import nltk
from nltk.corpus import stopwords


from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Activation, Conv1D, Dense, Embedding, Flatten, Input, Dropout, GlobalMaxPooling1D
from keras.metrics import categorical_accuracy
from keras.callbacks import  EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;-]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))
Number_RE = re.compile('[*^0-9]')
Bad_underline = re.compile('[*_*]')
RemoveTag = re.compile('&lt;|br&gt;|b&gt;|ul&gt;|li&gt;')

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = RemoveTag.sub('',text)
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = Number_RE.sub(' ', text) # replace Number symbols by space in text
    text = Bad_underline.sub(' ', text) # replace Underline symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text

# %%
def classNumberThreshold(arr):
    dropCategory = []

    for key,value in arr.items():
        if(value<=30):
            dropCategory.append(key)
    return dropCategory

# %%
df = pd.read_csv('../../example/fliptkart.csv')

# %%
df = df[pd.notnull(df['description'])]
df.description = df.description.apply(clean_text)
df = df[pd.notnull(df['category_main'])]
df = df[pd.notnull(df['pid'])]

# %%
dropCategoryCode  = classNumberThreshold(df.category_main.value_counts())
dropSubCategoryCode  = classNumberThreshold(df.category_sub1.value_counts())

for i in dropCategoryCode:
    df = df[df.category_main!=i]
    
for i in dropSubCategoryCode:
    df = df[df.category_sub1!=i]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17667 entries, 0 to 19997
# Data columns (total 8 columns):
# uniq_id          17667 non-null object
# product_url      17667 non-null object
# product_name     17667 non-null object
# pid              17667 non-null object
# description      17667 non-null object
# category_main    17667 non-null object
# category_sub1    17667 non-null object
# category_sub2    17667 non-null object
# dtypes: object(8)
# memory usage: 1.2+ MB

# %%
le = LabelEncoder()
le.fit(df.category_main)
target = le.classes_
labels = le.transform(df.category_main)

le.fit(df.category_sub1)
subtarget = le.classes_
sublabels = le.transform(df.category_sub1)

# %%
tfidfconverter = TfidfVectorizer(min_df=5, max_df=0.7)
X = tfidfconverter.fit_transform(df.description)

# %%
K = [2, 3, 4, 5, 10]
NBCresults = []
for ele in K:
    CNBC = ComplementNB()
    result = cross_validate(CNBC, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    NBCresults.append(result)
# Out:
# /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
SVCresults = []
for ele in K:
    linearsvc = LinearSVC(random_state=42, class_weight="balanced")
    result = cross_validate(linearsvc, X, labels, cv=ele , 
                   scoring = ('f1_micro','f1_macro','f1_weighted','accuracy'),return_train_score=True)
    SVCresults.append(result)

# %%
def result_report(results):
    mean_result_report = []
    for ele in results:
        mean_result = {}
        for key,value in ele.items():
            mean_result[key] = round(np.mean(value),2)
        mean_result_report.append(mean_result)
    return mean_result_report

NBCReport = result_report(NBCresults)
SVCReport = result_report(SVCresults)

# %%
NBCReport,SVCReport
# Out:
# ([{'fit_time': 0.02,
#    'score_time': 0.02,
#    'test_f1_micro': 0.9,
#    'train_f1_micro': 0.97,
#    'test_f1_macro': 0.77,
#    'train_f1_macro': 0.93,
#    'test_f1_weighted': 0.88,
#    'train_f1_weighted': 0.97,
#    'test_accuracy': 0.9,
#    'train_accuracy': 0.97},
#   {'fit_time': 0.02,
#    'score_time': 0.02,
#    'test_f1_micro': 0.92,
#    'train_f1_micro': 0.97,
#    'test_f1_macro': 0.84,
#    'train_f1_macro': 0.93,
#    'test_f1_weighted': 0.92,
#    'train_f1_weighted': 0.97,
#    'test_accuracy': 0.92,
#    'train_accuracy': 0.97},
#   {'fit_time': 0.02,
#    'score_time': 0.01,
#    'test_f1_micro': 0.94,
#    'train_f1_micro': 0.97,
#    'test_f1_macro': 0.85,
#    'train_f1_macro': 0.92,
#    'test_f1_weighted': 0.93,
#    'train_f1_weighted': 0.97,
#    'test_accuracy': 0.94,
#    'train_accuracy': 0.97},
#   {'fit_time': 0.02,
#    'score_time': 0.01,
#    'test_f1_micro': 0.94,
#    'train_f1_micro': 0.97,
#    'test_f1_macro': 0.85,
#    'train_f1_macro': 0.92,
#    'test_f1_weighted': 0.93,
#    'train_f1_weighted': 0.97,
#    'test_accuracy': 0.94,
#    'train_accuracy': 0.97},
#   {'fit_time': 0.02,
#    'score_time': 0.01,
#    'test_f1_micro': 0.95,
#    'train_f1_micro': 0.97,
#    'test_f1_macro': 0.87,
#    'train_f1_macro': 0.92,
#    'test_f1_weighted': 0.94,
#    'train_f1_weighted': 0.97,
#    'test_accuracy': 0.95,
#    'train_accuracy': 0.97}],
#  [{'fit_time': 0.44,
#    'score_time': 0.03,
#    'test_f1_micro': 0.91,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.82,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.91,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.91,
#    'train_accuracy': 1.0},
#   {'fit_time': 0.55,
#    'score_time': 0.02,
#    'test_f1_micro': 0.94,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.87,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.94,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.94,
#    'train_accuracy': 1.0},
#   {'fit_time': 0.64,
#    'score_time': 0.01,
#    'test_f1_micro': 0.96,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.9,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.96,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.96,
#    'train_accuracy': 1.0},
#   {'fit_time': 0.68,
#    'score_time': 0.01,
#    'test_f1_micro': 0.96,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.9,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.95,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.96,
#    'train_accuracy': 1.0},
#   {'fit_time': 0.75,
#    'score_time': 0.01,
#    'test_f1_micro': 0.97,
#    'train_f1_micro': 1.0,
#    'test_f1_macro': 0.92,
#    'train_f1_macro': 0.99,
#    'test_f1_weighted': 0.96,
#    'train_f1_weighted': 1.0,
#    'test_accuracy': 0.97,
#    'train_accuracy': 1.0}])

# %%
embedding_dim = 300 # We use 100 dimensional glove vectors
glove_dir = '../../glove.6B' # This is the folder with the dataset
embeddings_index = {} # We create a dictionary of word -> embedding
with open(os.path.join(glove_dir, 'glove.6B.300d.txt')) as f:
    for line in f:
        values = line.split()
        word = values[0] # The first value is the word, the rest are the values of the embedding
        embedding = np.asarray(values[1:], dtype='float32') # Load embedding
        embeddings_index[word] = embedding # Add embedding to our embedding dictionary
    print('Found {:,} word vectors in GloVe.'.format(len(embeddings_index)))
# Out:
# Found 400,000 word vectors in GloVe.

# %%
def tokenizer_and_pad_sequence (Xtrain,Xtest,vocab_size,embeddings_index):
    tokenizer = Tokenizer(num_words=vocab_size) # Setup tokenizer
    tokenizer.fit_on_texts(Xtrain)
    
    sequences = tokenizer.texts_to_sequences(Xtrain)
    sequences_test = tokenizer.texts_to_sequences(Xtest)
    
    trainlengths = [len(ele) for ele in sequences]
    testlengths = [len(ele) for ele in sequences_test]
    max_length = min(max(trainlengths),max(testlengths))
    
    train = pad_sequences(sequences,maxlen= max_length)
    test = pad_sequences(sequences_test,maxlen = max_length)
    
    word_index = tokenizer.word_index
    embedding_dim = 300
    nb_words = min(vocab_size, len(word_index)) # How many words are there actually
    embedding_matrix = np.zeros((nb_words, embedding_dim))
    # The vectors need to be in the same position as their index. 
    # Meaning a word with token 1 needs to be in the second row (rows start with zero) and so on
    # Loop over all words in the word index
    for word, i in word_index.items():
        # If we are above the amount of words we want to use we do nothing
        if i >= vocab_size: 
            continue
        # Get the embedding vector for the word
        embedding_vector = embeddings_index.get(word)
        # If there is an embedding vector, put it in the embedding matrix
        if embedding_vector is not None: 
            embedding_matrix[i] = embedding_vector
    return train, test, max_length, embedding_matrix

def model_settings(length,vocabSize,embeddingMatrix,outputnum):
        embedding_dim = 300
        model = Sequential()
        model.add(Embedding(vocab_size, embedding_dim, input_length=length, weights = [embedding_matrix], 
                                trainable = False))
        model.add(Conv1D(200,3,padding='valid',activation='relu',strides=1))        
        # we use max pooling:
        model.add(GlobalMaxPooling1D())
        # We add a vanilla hidden layer:
        model.add(Dense(250))
        model.add(Dropout(0.2))
        model.add(Dense(outputnum, activation='softmax'))
        model.summary()
        return model

def fit_evaluate(model,Xtrain, ytrain,Xtest,ytest):
    EPOCHS = 10
    BATCH_SIZE = 100
    #set early stopping criteria
    pat = 5 #this is the number of epochs with no improvment after which the training will stop
    early_stopping = EarlyStopping(monitor='val_loss', patience=pat, verbose=1)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[categorical_accuracy])
    result = model.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=BATCH_SIZE, 
                        callbacks=[early_stopping], 
              verbose=1, validation_split=0.1)
    score = model.evaluate(Xtest, ytest, batch_size=BATCH_SIZE)
    return result,score

# %%
vocab_size = len(tfidfconverter.get_feature_names())
KFoldTrainResults = []
KFoldTestResults  = []
for i in testSize:
    print("------ "+str(i)+" testing size ------\n")
    Xtrain, Xtest, ytrain , ytest = train_test_split(df['description'].apply(str), labels, test_size= i, random_state = 42)
    categoricalLabel = to_categorical(ytrain)
    categoricalTestLabel = to_categorical(ytest)
    train, test, max_length, embedding_matrix =  tokenizer_and_pad_sequence(Xtrain,Xtest,vocab_size,embeddings_index)
    model = model_settings(max_length,vocab_size,embedding_matrix,len(np.unique(ytrain)))
    result,score = fit_evaluate(model,train,categoricalLabel,test,categoricalTestLabel)
    KFoldTrainResults.append(result)
    KFoldTestResults.append(score)
# Out:
# ------ 0.5 testing size ------
# WARNING: Logging before flag parsing goes to stderr.
# W0803 00:38:04.775256 4359759296 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0803 00:38:04.793545 4359759296 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0803 00:38:04.796762 4359759296 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0803 00:38:04.806833 4359759296 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0803 00:38:04.807675 4359759296 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0803 00:38:04.900310 4359759296 deprecation.py:506] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0803 00:38:04.930906 4359759296 deprecation_wrapper.py:119] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0803 00:38:04.955029 4359759296 deprecation.py:323] From /Users/apple/Desktop/projects/uob-msc50-project/classification/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 410, 300)          1759800
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 408, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 22)                5522
# =================================================================
# Total params: 1,995,772
# Trainable params: 235,972
# Non-trainable params: 1,759,800
# _________________________________________________________________
# Train on 7949 samples, validate on 884 samples
# Epoch 1/10
# 7949/7949 [==============================] - 14s 2ms/step - loss: 0.0482 - categorical_accuracy: 0.8137 - val_loss: 0.0159 - val_categorical_accuracy: 0.9355
# Epoch 2/10
# 7949/7949 [==============================] - 15s 2ms/step - loss: 0.0100 - categorical_accuracy: 0.9660 - val_loss: 0.0079 - val_categorical_accuracy: 0.9683
# Epoch 3/10
# 7949/7949 [==============================] - 16s 2ms/step - loss: 0.0048 - categorical_accuracy: 0.9840 - val_loss: 0.0073 - val_categorical_accuracy: 0.9661
# Epoch 4/10
# 7949/7949 [==============================] - 16s 2ms/step - loss: 0.0024 - categorical_accuracy: 0.9930 - val_loss: 0.0066 - val_categorical_accuracy: 0.9729
# Epoch 5/10
# 7949/7949 [==============================] - 15s 2ms/step - loss: 0.0014 - categorical_accuracy: 0.9964 - val_loss: 0.0053 - val_categorical_accuracy: 0.9830
# Epoch 6/10
# 7949/7949 [==============================] - 15s 2ms/step - loss: 0.0011 - categorical_accuracy: 0.9966 - val_loss: 0.0055 - val_categorical_accuracy: 0.9785
# Epoch 7/10
# 7949/7949 [==============================] - 14s 2ms/step - loss: 9.9801e-04 - categorical_accuracy: 0.9974 - val_loss: 0.0050 - val_categorical_accuracy: 0.9819
# Epoch 8/10
# 7949/7949 [==============================] - 14s 2ms/step - loss: 6.3907e-04 - categorical_accuracy: 0.9979 - val_loss: 0.0044 - val_categorical_accuracy: 0.9842
# Epoch 9/10
# 7949/7949 [==============================] - 15s 2ms/step - loss: 7.3888e-04 - categorical_accuracy: 0.9986 - val_loss: 0.0056 - val_categorical_accuracy: 0.9785
# Epoch 10/10
# 7949/7949 [==============================] - 15s 2ms/step - loss: 6.7471e-04 - categorical_accuracy: 0.9981 - val_loss: 0.0071 - val_categorical_accuracy: 0.9751
# 8834/8834 [==============================] - 7s 777us/step
# ------ 0.3333333333333333 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 410, 300)          1759800
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 408, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 200)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 22)                5522
# =================================================================
# Total params: 1,995,772
# Trainable params: 235,972
# Non-trainable params: 1,759,800
# _________________________________________________________________
# Train on 10600 samples, validate on 1178 samples
# Epoch 1/10
# 10600/10600 [==============================] - 20s 2ms/step - loss: 0.0398 - categorical_accuracy: 0.8483 - val_loss: 0.0119 - val_categorical_accuracy: 0.9576
# Epoch 2/10
# 10600/10600 [==============================] - 20s 2ms/step - loss: 0.0077 - categorical_accuracy: 0.9747 - val_loss: 0.0072 - val_categorical_accuracy: 0.9711
# Epoch 3/10
# 10600/10600 [==============================] - 20s 2ms/step - loss: 0.0034 - categorical_accuracy: 0.9903 - val_loss: 0.0054 - val_categorical_accuracy: 0.9771
# Epoch 4/10
# 10600/10600 [==============================] - 20s 2ms/step - loss: 0.0023 - categorical_accuracy: 0.9935 - val_loss: 0.0043 - val_categorical_accuracy: 0.9847
# Epoch 5/10
# 10600/10600 [==============================] - 20s 2ms/step - loss: 0.0014 - categorical_accuracy: 0.9957 - val_loss: 0.0047 - val_categorical_accuracy: 0.9813
# Epoch 6/10
# 10600/10600 [==============================] - 20s 2ms/step - loss: 0.0011 - categorical_accuracy: 0.9967 - val_loss: 0.0053 - val_categorical_accuracy: 0.9830
# Epoch 7/10
# 10600/10600 [==============================] - 20s 2ms/step - loss: 8.5060e-04 - categorical_accuracy: 0.9978 - val_loss: 0.0051 - val_categorical_accuracy: 0.9805
# Epoch 8/10
# 10600/10600 [==============================] - 20s 2ms/step - loss: 8.0514e-04 - categorical_accuracy: 0.9974 - val_loss: 0.0052 - val_categorical_accuracy: 0.9805
# Epoch 9/10
# 10600/10600 [==============================] - 20s 2ms/step - loss: 9.1535e-04 - categorical_accuracy: 0.9977 - val_loss: 0.0052 - val_categorical_accuracy: 0.9813
# Epoch 00009: early stopping
# 5889/5889 [==============================] - 5s 797us/step
# ------ 0.25 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 404, 300)          1759800
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 402, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 200)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 22)                5522
# =================================================================
# Total params: 1,995,772
# Trainable params: 235,972
# Non-trainable params: 1,759,800
# _________________________________________________________________
# Train on 11925 samples, validate on 1325 samples
# Epoch 1/10
# 11925/11925 [==============================] - 22s 2ms/step - loss: 0.0372 - categorical_accuracy: 0.8599 - val_loss: 0.0106 - val_categorical_accuracy: 0.9562
# Epoch 2/10
# 11925/11925 [==============================] - 22s 2ms/step - loss: 0.0066 - categorical_accuracy: 0.9773 - val_loss: 0.0066 - val_categorical_accuracy: 0.9713
# Epoch 3/10
# 11925/11925 [==============================] - 22s 2ms/step - loss: 0.0034 - categorical_accuracy: 0.9903 - val_loss: 0.0060 - val_categorical_accuracy: 0.9796
# Epoch 4/10
# 11925/11925 [==============================] - 22s 2ms/step - loss: 0.0021 - categorical_accuracy: 0.9930 - val_loss: 0.0044 - val_categorical_accuracy: 0.9849
# Epoch 5/10
# 11925/11925 [==============================] - 22s 2ms/step - loss: 0.0017 - categorical_accuracy: 0.9943 - val_loss: 0.0044 - val_categorical_accuracy: 0.9834
# Epoch 6/10
# 11925/11925 [==============================] - 22s 2ms/step - loss: 8.4414e-04 - categorical_accuracy: 0.9970 - val_loss: 0.0040 - val_categorical_accuracy: 0.9849
# Epoch 7/10
# 11925/11925 [==============================] - 22s 2ms/step - loss: 0.0011 - categorical_accuracy: 0.9970 - val_loss: 0.0050 - val_categorical_accuracy: 0.9819
# Epoch 8/10
# 11925/11925 [==============================] - 23s 2ms/step - loss: 9.6177e-04 - categorical_accuracy: 0.9969 - val_loss: 0.0043 - val_categorical_accuracy: 0.9842
# Epoch 9/10
# 11925/11925 [==============================] - 22s 2ms/step - loss: 4.6638e-04 - categorical_accuracy: 0.9986 - val_loss: 0.0042 - val_categorical_accuracy: 0.9849
# Epoch 10/10
# 11925/11925 [==============================] - 26s 2ms/step - loss: 5.5605e-04 - categorical_accuracy: 0.9983 - val_loss: 0.0052 - val_categorical_accuracy: 0.9834
# 4417/4417 [==============================] - 3s 773us/step
# ------ 0.2 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 404, 300)          1759800
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 402, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 200)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 22)                5522
# =================================================================
# Total params: 1,995,772
# Trainable params: 235,972
# Non-trainable params: 1,759,800
# _________________________________________________________________
# Train on 12719 samples, validate on 1414 samples
# Epoch 1/10
# 12719/12719 [==============================] - 28s 2ms/step - loss: 0.0340 - categorical_accuracy: 0.8707 - val_loss: 0.0094 - val_categorical_accuracy: 0.9682
# Epoch 2/10
# 12719/12719 [==============================] - 26s 2ms/step - loss: 0.0063 - categorical_accuracy: 0.9796 - val_loss: 0.0064 - val_categorical_accuracy: 0.9745
# Epoch 3/10
# 12719/12719 [==============================] - 29s 2ms/step - loss: 0.0032 - categorical_accuracy: 0.9897 - val_loss: 0.0060 - val_categorical_accuracy: 0.9809
# Epoch 4/10
# 12719/12719 [==============================] - 26s 2ms/step - loss: 0.0020 - categorical_accuracy: 0.9938 - val_loss: 0.0041 - val_categorical_accuracy: 0.9859
# Epoch 5/10
# 12719/12719 [==============================] - 26s 2ms/step - loss: 0.0012 - categorical_accuracy: 0.9965 - val_loss: 0.0062 - val_categorical_accuracy: 0.9816
# Epoch 6/10
# 12719/12719 [==============================] - 28s 2ms/step - loss: 0.0016 - categorical_accuracy: 0.9950 - val_loss: 0.0043 - val_categorical_accuracy: 0.9844
# Epoch 7/10
# 12719/12719 [==============================] - 30s 2ms/step - loss: 0.0012 - categorical_accuracy: 0.9965 - val_loss: 0.0037 - val_categorical_accuracy: 0.9866
# Epoch 8/10
# 12719/12719 [==============================] - 30s 2ms/step - loss: 9.5675e-04 - categorical_accuracy: 0.9977 - val_loss: 0.0033 - val_categorical_accuracy: 0.9880
# Epoch 9/10
# 12719/12719 [==============================] - 32s 3ms/step - loss: 9.0128e-04 - categorical_accuracy: 0.9972 - val_loss: 0.0046 - val_categorical_accuracy: 0.9851
# Epoch 10/10
# 12719/12719 [==============================] - 31s 2ms/step - loss: 7.2504e-04 - categorical_accuracy: 0.9978 - val_loss: 0.0050 - val_categorical_accuracy: 0.9837
# 3534/3534 [==============================] - 4s 1ms/step
# ------ 0.1 testing size ------
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 404, 300)          1759800
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 402, 200)          180200
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 200)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 250)               50250
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 22)                5522
# =================================================================
# Total params: 1,995,772
# Trainable params: 235,972
# Non-trainable params: 1,759,800
# _________________________________________________________________
# Train on 14310 samples, validate on 1590 samples
# Epoch 1/10
# 14310/14310 [==============================] - 35s 2ms/step - loss: 0.0329 - categorical_accuracy: 0.8771 - val_loss: 0.0090 - val_categorical_accuracy: 0.9723
# Epoch 2/10
# 14310/14310 [==============================] - 31s 2ms/step - loss: 0.0060 - categorical_accuracy: 0.9790 - val_loss: 0.0062 - val_categorical_accuracy: 0.9761
# Epoch 3/10
# 14310/14310 [==============================] - 32s 2ms/step - loss: 0.0031 - categorical_accuracy: 0.9897 - val_loss: 0.0037 - val_categorical_accuracy: 0.9862
# Epoch 4/10
# 14310/14310 [==============================] - 43s 3ms/step - loss: 0.0023 - categorical_accuracy: 0.9936 - val_loss: 0.0056 - val_categorical_accuracy: 0.9755
# Epoch 5/10
# 14310/14310 [==============================] - 55s 4ms/step - loss: 0.0014 - categorical_accuracy: 0.9960 - val_loss: 0.0043 - val_categorical_accuracy: 0.9881
# Epoch 6/10
# 14310/14310 [==============================] - 53s 4ms/step - loss: 9.6590e-04 - categorical_accuracy: 0.9973 - val_loss: 0.0044 - val_categorical_accuracy: 0.9855
# Epoch 7/10
# 14310/14310 [==============================] - 52s 4ms/step - loss: 0.0013 - categorical_accuracy: 0.9958 - val_loss: 0.0056 - val_categorical_accuracy: 0.9830
# Epoch 8/10
# 14310/14310 [==============================] - 52s 4ms/step - loss: 0.0012 - categorical_accuracy: 0.9968 - val_loss: 0.0050 - val_categorical_accuracy: 0.9868
# Epoch 00008: early stopping
# 1767/1767 [==============================] - 3s 2ms/step

# %%
fig, (ax,ax2) = plt.subplots(2, 1,figsize=(5,10))
for ele in KFoldTrainResults:
    currentTestsize = testSize[KFoldTrainResults.index(ele)]
    ax.plot(ele.history['categorical_accuracy'],label= str(round(1-currentTestsize,2))+" testing size")

    ax.legend()
ax.set_title('Categorical Accuracy Accuracy')
ax.set_xlabel("Epoch")
ax.set_ylabel("Validation categoryical accuracy")

for ele in KFoldTrainResults:
    currentTestsize = testSize[KFoldTrainResults.index(ele)]
    ax2.plot(ele.history['val_categorical_accuracy'],label= str(round(1-currentTestsize,2))+" testing size")
    ax2.legend()
ax2.set_title('Validation categoryical accuracy')
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Validation categoryical accuracy")

fig.savefig("FlipkartCNNsTrainCrossValidation.png", bbox_inches='tight')

# %%
fig, (ax1,ax3) = plt.subplots(2, 1,figsize=(5,10))
fig.subplots_adjust(hspace=0.5)
testSize = [ 1/ele for ele in K ]
ytrainTimeNBC = [ ele['fit_time'] for ele in NBCReport]
ytrainTimeSVC = [ ele['fit_time'] for ele in SVCReport]
ytestTimeNBC = [ ele['score_time'] for ele in NBCReport]
ytestTimeSVC = [ ele['score_time'] for ele in SVCReport]
yAccCNNs = [ele[1] for ele in KFoldTestResults]
yAccNBC = [ ele['test_accuracy'] for ele in NBCReport]
yAccSVC = [ ele['test_accuracy'] for ele in SVCReport]
line1, = ax1.plot(testSize, ytrainTimeNBC, color="tab:blue", label = "CNBC Training" )
line2, = ax1.plot(testSize, ytrainTimeSVC, color="tab:orange", label = "SVC Training" )
line1.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break
line2.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break

ax1.set_title('Training and Testing Time')
ax1.set_xlabel("Size of testing set")
ax1.set_ylabel("Training time (us)")
step1 = (max(ytrainTimeSVC) - min(ytrainTimeSVC))/len(ytrainTimeSVC)
ax1.yaxis.set_ticks(np.arange(0,max(ytrainTimeSVC),step1))
ax1.xaxis.set_ticks(np.arange(0,1,0.1))

# ax1.grid()
ax1.legend(loc=4)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(testSize, ytestTimeNBC, color="tab:blue", label = "CNBC Testing" )
ax2.plot(testSize, ytestTimeSVC, color="tab:orange", label = "SVC Testing" )
ax2.set_ylabel("Testing time (us)")
step2 = (max(ytestTimeSVC) - min(ytestTimeSVC))/len(ytestTimeSVC)
ax2.yaxis.set_ticks(np.arange(0,max(ytestTimeSVC),step2))
# ax2.grid()
ax2.legend(loc=1)

ax3.plot(testSize, yAccNBC, color="tab:blue", label = "CNBC" )
ax3.plot(testSize, yAccSVC, color="tab:orange", label = "SVC" )
ax3.plot(testSize, yAccCNNs, color="tab:red", label = "CNNs" )
ax3.set_title('Accuracy')
ax3.set_xlabel("Size of testing set")
ax3.set_ylabel("Accuracy")

ax3.grid()
ax3.legend()

fig.savefig("FlipkartCrossValidation.png", bbox_inches='tight')

print(K[np.argmax(yAccSVC)])
print(K[np.argmax(yAccCNNs)])
# Out:
# 10
# 5
